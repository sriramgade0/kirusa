# %%
import csv

# Define the headers
headers = [
    "id",
    "Name",
    "Desc (Kirusa type of writing)",
    "Desc (Preparation)",
    "Photo",
    "Region",
    "Time of Eating (B)",
    "Time of Eating (L)",
    "Time of Eating (D)",
    "Food Type",
    "Ratings",
    "Ingredients",
    "Calories",
    "Fat",
    "Protein",
    "Cholesterol",
    "Sodium",
    "Saturated Fat",
    "Sugar",
    "Type",
    "Food Type (Veg/Non-Veg/Vegan)",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)",
    "Category (Muscle Gain)"
]

# Example data row
data = [
    1, 
    "Grilled Chicken", 
    "Flavorful grilled chicken recipe", 
    "Grill for 20 minutes", 
    "https://example.com/photo.jpg", 
    "USA", 
    True, 
    True, 
    False, 
    "Muscle Gain, Diabetic", 
    4, 
    "Chicken, Olive Oil, Spices", 
    500, 
    20, 
    30, 
    80, 
    300, 
    5, 
    0, 
    "Non-Veg", 
    "Main Course", 
    "Lunch", 
    "Diabetic, Muscle Gain"
]

# Write to a CSV file
with open("food_data.csv", "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(headers)  # Write the headers
    csvwriter.writerow(data)     # Write a single row of data

# %%
data
# Out:
# [1,
#  'Grilled Chicken',
#  'Flavorful grilled chicken recipe',
#  'Grill for 20 minutes',
#  'https://example.com/photo.jpg',
#  'USA',
#  True,
#  True,
#  False,
#  'Muscle Gain, Diabetic',
#  4,
#  'Chicken, Olive Oil, Spices',
#  500,
#  20,
#  30,
#  80,
#  300,
#  5,
#  0,
#  'Non-Veg',
#  'Main Course',
#  'Lunch',
#  'Diabetic, Muscle Gain']

# %%
import pandas as pd

# %%
df = pd.read_csv("food_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("food_data.csv")
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#    id             Name     Desc (Kirusa type of writing)  \
# 0   1  Grilled Chicken  Flavorful grilled chicken recipe
#
#      Desc (Preparation)                          Photo Region  \
# 0  Grill for 20 minutes  https://example.com/photo.jpg    USA
#
#    Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0                True                True               False
#
#                Food Type  ...  Protein Cholesterol  Sodium  Saturated Fat  \
# 0  Muscle Gain, Diabetic  ...       30          80     300              5
#
#    Sugar     Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Non-Veg                    Main Course
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  Category (Diabetic/BP)  \
# 0                                              Lunch   Diabetic, Muscle Gain
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 24 columns]

# %%
recipes = [
    # Breakfast Recipes
    "Idli", "Dosa", "Uttapam", "Upma", "Pongal", "Rava Idli", "Appam", "Puttu", 
    "Neer Dosa", "Kanchipuram Idli", "Masala Dosa", "Onion Uttapam", "Adai", 
    "Semiya Upma (Vermicelli Upma)", "Ragi Dosa", "Wheat Dosa", "Kara Paniyaram", 
    "Thatte Idli", "Kal Dosa", "Set Dosa", 
    
    # Snacks and Starters
    "Medu Vada", "Masala Vada", "Thattai", "Banana Chips", "Murukku", "Bonda (Potato Bonda)", 
    "Sundal (Chickpea Sundal)", "Masala Bajji (Chili Bajji)", "Onion Pakoda", "Ribbon Pakoda", 
    "Omapodi", "Maddur Vada", "Keerai Vada (Spinach Fritters)", "Rava Kesari (Sweet Snack)", 
    "Thenguzhal", "Mysore Bonda", "Aval Mixture (Beaten Rice Snack)", "Aloo Bajji", 
    "Vazhakkai Bajji (Raw Banana Fritters)", "Murungai Keerai Soup (Drumstick Leaf Soup)", 
    
    # Curries and Gravies
    "Sambar", "Rasam", "Avial", "Vatha Kuzhambu", "Puli Kuzhambu (Tamarind Curry)", 
    "Mor Kuzhambu (Buttermilk Curry)", "Kozhi Kuzhambu (Chicken Curry)", "Erissery (Pumpkin Curry)", 
    "Theeyal (Roasted Coconut Curry)", "Chettinad Chicken Curry", "Mutton Sukka", 
    "Meen Kuzhambu (Fish Curry)", "Chepala Pulusu (Andhra Fish Curry)", "Gongura Mutton Curry", 
    "Kootu Curry", "Kadalai Kuzhambu (Chickpea Curry)", "Potato Kurma", 
    "Vendakkai Puli Kuzhambu (Okra Tamarind Curry)", "Tomato Rasam", "Paruppu Urundai Kuzhambu (Lentil Ball Curry)", 
    
    # Rice Dishes
    "Lemon Rice", "Coconut Rice", "Tamarind Rice", "Curd Rice", "Tomato Rice", 
    "Biryani (Ambur Style)", "Hyderabadi Dum Biryani", "Puliyodarai (Tamarind Rice)", 
    "Ghee Rice", "Vegetable Biryani", "Mushroom Biryani", "Pongal (Ven Pongal)", 
    "Khara Pongal", "Chicken Biryani", "Mutton Biryani", "Prawn Biryani", "Kichadi", 
    "Pulihora (Andhra Tamarind Rice)", "Kovakkai Rice (Ivy Gourd Rice)", "Beetroot Rice", 
    
    # Side Dishes
    "Coconut Chutney", "Tomato Chutney", "Onion Chutney", "Mint Chutney", "Peanut Chutney", 
    "Coriander Chutney", "Kara Chutney (Spicy Tomato Chutney)", "Gongura Pachadi (Roselle Leaf Chutney)", 
    "Pudina Thogayal (Mint Chutney Paste)", "Paruppu Thogayal (Lentil Chutney Paste)", 
    "Ridge Gourd Chutney", "Brinjal Chutney", "Capsicum Chutney", "Garlic Chutney", 
    "Red Chilli Chutney", "Curry Leaves Powder", "Idli Podi (Gunpowder Chutney)", "Dahi Chutney", 
    "Green Chutney", "Tamarind Chutney", 
    
    # Snacks & Tiffin Dishes
    "Kozhukattai (Modak)", "Sweet Pongal", "Ela Ada (Steamed Rice Dumpling)", "Rava Kesari", 
    "Mysore Pak", "Badusha", "Puran Poli (Sweet Flatbread)", "Banana Halwa", "Coconut Burfi", 
    "Milk Kesari", "Kumbakonam Degree Coffee", "Payasam (Rice Kheer)", "Paal Payasam", 
    "Semiya Payasam", "Adhirasam", "Thirunelveli Halwa", "Boondi Ladoo", 
    "Jalebi (South Indian Version)", "Mysore Masala Dosa", "Vella Seedai", 
    
    # Non-Vegetarian Dishes
    "Mutton Curry", "Mutton Chukka", "Andhra Style Chicken Fry", "Chicken Chettinad", 
    "Chicken 65", "Prawn Masala", "Crab Curry", "Nethili Fry (Anchovy Fry)", 
    "Fish Fry (Meen Varuval)", "Chicken Varuval", "Duck Curry", "Egg Masala", 
    "Egg Podimas (Scrambled Eggs)", "Andhra Kodi Kura (Chicken Curry)", "Kerala Fish Curry", 
    "Mutton Biryani", "Chicken Sukka", "Pepper Chicken", "Prawn Thokku", "Nandu Rasam (Crab Soup)", 
    
    # Vegetarian Dishes
    "Poriyal (Vegetable Stir Fry)", "Beans Poriyal", "Beetroot Poriyal", "Cabbage Poriyal", 
    "Potato Fry", "Carrot Thoran", "Bhindi Fry (Okra Fry)", "Brinjal Fry (Kathirikai Poriyal)", 
    "Drumstick Curry", "Plantain Curry (Vazhakkai Poriyal)", "Keerai Masiyal (Spinach Curry)", 
    "Sundakkai Vatha Kuzhambu (Turkey Berry Curry)", "Ennai Kathirikai (Stuffed Brinjal)", 
    "Kaalan Curry (Yam Curry)", "Vazhaipoo Vadai (Banana Flower Fritters)", 
    "Thakkali Pachadi (Tomato Yogurt Side Dish)", "Raw Mango Pachadi", 
    "Chettinad Vendakkai Curry (Ladyfinger Curry)", "Soya Chunks Curry", "Cabbage Kofta", 
    
    # Desserts
    "Palada Payasam", "Kesari Bath", "Badam Halwa", "Coconut Laddu", "Rice Kheer", 
    "Jaggery Payasam", "Ada Pradhaman", "Ariselu", "Boondi Ladoo", "Carrot Halwa", 
    "Mango Kesari", "Chakkara Pongal (Sweet Pongal)", "Sweet Kozhukattai", "Banana Appam", 
    "Paal Kozhukattai", "Neyyappam", "Aval Payasam", "Jackfruit Halwa", "Ragi Halwa", 
    "Wheat Halwa", 
    
    # Drinks
    "Filter Coffee", "Masala Chai", "Tender Coconut Water", "Buttermilk (Neer Mor)", 
    "Jigarthanda", "Nannari Sarbath", "Panakam", "Tamarind Drink", "Mango Juice", 
    "Pineapple Pachadi (Juice-Like Dessert)", "Badam Milk", "Sukku Coffee", "Herbal Kashayam", 
    "Cucumber Mint Cooler", "Coconut Milk with Jaggery", "Lemon Rasam", "Beetroot Juice", 
    "Ginger Lemon Tea", "Tulsi Tea", "Kambu Koozh (Pearl Millet Drink)"
]

# %%
recipes
# Out:
# ['Idli',
#  'Dosa',
#  'Uttapam',
#  'Upma',
#  'Pongal',
#  'Rava Idli',
#  'Appam',
#  'Puttu',
#  'Neer Dosa',
#  'Kanchipuram Idli',
#  'Masala Dosa',
#  'Onion Uttapam',
#  'Adai',
#  'Semiya Upma (Vermicelli Upma)',
#  'Ragi Dosa',
#  'Wheat Dosa',
#  'Kara Paniyaram',
#  'Thatte Idli',
#  'Kal Dosa',
#  'Set Dosa',
#  'Medu Vada',
#  'Masala Vada',
#  'Thattai',
#  'Banana Chips',
#  'Murukku',
#  'Bonda (Potato Bonda)',
#  'Sundal (Chickpea Sundal)',
#  'Masala Bajji (Chili Bajji)',
#  'Onion Pakoda',
#  'Ribbon Pakoda',
#  'Omapodi',
#  'Maddur Vada',
#  'Keerai Vada (Spinach Fritters)',
#  'Rava Kesari (Sweet Snack)',
#  'Thenguzhal',
#  'Mysore Bonda',
#  'Aval Mixture (Beaten Rice Snack)',
#  'Aloo Bajji',
#  'Vazhakkai Bajji (Raw Banana Fritters)',
#  'Murungai Keerai Soup (Drumstick Leaf Soup)',
#  'Sambar',
#  'Rasam',
#  'Avial',
#  'Vatha Kuzhambu',
#  'Puli Kuzhambu (Tamarind Curry)',
#  'Mor Kuzhambu (Buttermilk Curry)',
#  'Kozhi Kuzhambu (Chicken Curry)',
# ...

# %%
df = pd.DataFrame({"Name": recipes})

# Save the DataFrame to a CSV file
df.to_csv("food_data.csv", index=False)

print("CSV file 'south_indian_recipes.csv' has been created successfully!")
# Out:
# CSV file 'south_indian_recipes.csv' has been created successfully!

# %%
df
# Out:
#                                  Name
# 0                                Idli
# 1                                Dosa
# 2                             Uttapam
# 3                                Upma
# 4                              Pongal
# ..                                ...
# 195                       Lemon Rasam
# 196                    Beetroot Juice
# 197                  Ginger Lemon Tea
# 198                         Tulsi Tea
# 199  Kambu Koozh (Pearl Millet Drink)
#
# [200 rows x 1 columns]

# %%
headers = [
    "Name",
    "Desc (Kirusa type of writing)",
    "Desc (Preparation)",
    "Photo",
    "Region",
    "Time of Eating (B)",
    "Time of Eating (L)",
    "Time of Eating (D)",
    "Food Type",
    "Ratings",
    "Ingredients",
    "Calories",
    "Fat",
    "Protein",
    "Cholesterol",
    "Sodium",
    "Saturated Fat",
    "Sugar",
    "Type",
    "Food Type (Veg/Non-Veg/Vegan)",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)",
    "Category (Muscle Gain)"
]

# %%
import numpy as np
for i in headers:
    if i != "Name":
        df[i] = np.nan

# %%
df
# Out:
#                                  Name  Desc (Kirusa type of writing)  \
# 0                                Idli                            NaN
# 1                                Dosa                            NaN
# 2                             Uttapam                            NaN
# 3                                Upma                            NaN
# 4                              Pongal                            NaN
# ..                                ...                            ...
# 195                       Lemon Rasam                            NaN
# 196                    Beetroot Juice                            NaN
# 197                  Ginger Lemon Tea                            NaN
# 198                         Tulsi Tea                            NaN
# 199  Kambu Koozh (Pearl Millet Drink)                            NaN
#
#      Desc (Preparation)  Photo  Region  Time of Eating (B)  \
# 0                   NaN    NaN     NaN                 NaN
# ...

# %%
df.to_csv("food_data.csv", index=False)

# %%
df
# Out:
#                                  Name  Desc (Kirusa type of writing)  \
# 0                                Idli                            NaN
# 1                                Dosa                            NaN
# 2                             Uttapam                            NaN
# 3                                Upma                            NaN
# 4                              Pongal                            NaN
# ..                                ...                            ...
# 195                       Lemon Rasam                            NaN
# 196                    Beetroot Juice                            NaN
# 197                  Ginger Lemon Tea                            NaN
# 198                         Tulsi Tea                            NaN
# 199  Kambu Koozh (Pearl Millet Drink)                            NaN
#
#      Desc (Preparation)  Photo  Region  Time of Eating (B)  \
# 0                   NaN    NaN     NaN                 NaN
# ...

# %%
style = """
### **Recipe Template**

#### 1. **Dish Name**  
> Example: **Idli**

#### 2. **Description**  
> A short, 2-3 sentence introduction to the dish. Include its significance, origin, or when it is typically served.  
> *Example:*  
> Idli is a soft, fluffy steamed rice cake that is a staple breakfast dish in South India. It is healthy, light, and pairs perfectly with chutneys and sambar.

---

#### 3. **Ingredients**  
List all ingredients with their measurements. Group them logically (e.g., main ingredients, spices, etc.).

- **For Batter:**
  - 1 cup rice
  - 1/4 cup urad dal
  - 1/2 tsp fenugreek seeds
  - Water (as required)
- **For Steaming:**
  - Oil (for greasing the idli molds)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 6-8 hours (for soaking and fermenting)  
- **Cooking Time:** 10-15 minutes  
- **Total Time:** ~8 hours 15 minutes  

---

#### 5. **How to Prepare**  

**Step-by-Step Instructions:**  
1. **Soak Ingredients:**  
   Wash the rice and urad dal separately. Soak them along with fenugreek seeds for 6 hours.

2. **Grind Batter:**  
   Grind the soaked urad dal into a smooth paste. Then grind the rice into a slightly coarse batter. Combine both, add salt, and mix well.

3. **Ferment Batter:**  
   Allow the batter to ferment overnight or for 8 hours in a warm place. The batter should rise and become light.

4. **Steam Idlis:**  
   Grease idli molds with oil, pour the batter, and steam for 10-15 minutes in an idli steamer.

5. **Serve:**  
   Serve hot with coconut chutney and sambar.

---

#### 6. **Tips**  
Add some tips or variations to make the dish unique:  
- Use leftover idlis to make masala idli or fry them for a snack.  
- Adjust fermentation time based on the climate. Warm weather speeds up fermentation.

---

#### 7. **Serving Suggestions**  
Suggest ways to serve the dish:  
- Serve with sambar, coconut chutney, or tomato chutney.  
- Add a dollop of ghee on top for extra flavor.

---

#### 8. **Nutritional Information** *(Optional)*  
Provide an approximate breakdown of the nutritional value per serving.  
- **Calories:** 120 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 22 g  
- **Fat:** 0.5 g  

---"""

# %%
if df["Name"] == "idli":
    df["Desc (Kirusa type of writing)"][0] = style
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23352\2761539778.py in ?()
# ----> 1 if df["Name"] == "idli":
#       2     df["Desc (Kirusa type of writing)"][0] = style
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
type(style)
# Out:
# str

# %%
df["Desc (Kirusa type of writing)"].astype(object)
# Out:
# 0      \n### **Recipe Template**\n\n#### 1. **Dish Na...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 195                                                  NaN
# 196                                                  NaN
# 197                                                  NaN
# 198                                                  NaN
# 199                                                  NaN
# Name: Desc (Kirusa type of writing), Length: 200, dtype: object

# %%
df["Desc (Kirusa type of writing)"][0] = style

# %%
df.columns
# Out:
# Index(['Name', 'Desc (Kirusa type of writing)', 'Desc (Preparation)', 'Photo',
#        'Region', 'Time of Eating (B)', 'Time of Eating (L)',
#        'Time of Eating (D)', 'Food Type', 'Ratings', 'Ingredients', 'Calories',
#        'Fat', 'Protein', 'Cholesterol', 'Sodium', 'Saturated Fat', 'Sugar',
#        'Type', 'Food Type (Veg/Non-Veg/Vegan)',
#        'Category (Breakfast/Lunch/Dinner/Snack/Beverages)',
#        'Category (Diabetic/BP)', 'Category (Muscle Gain)'],
#       dtype='object')

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Idli

#### 2. **Description**  
> Idli is a soft, fluffy steamed rice cake that is a staple breakfast dish in South India. It is healthy, light, and pairs perfectly with chutneys and sambar.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup rice
  - 1/4 cup urad dal
  - 1/2 tsp fenugreek seeds
  - Water (as required)
- **For Steaming:**
  - Oil (for greasing the idli molds)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 6-8 hours (for soaking and fermenting)  
- **Cooking Time:** 10-15 minutes  
- **Total Time:** ~8 hours 15 minutes  

---

#### 5. **How to Prepare**  
1. Soak Ingredients: Wash the rice and urad dal separately. Soak them along with fenugreek seeds for 6 hours.
2. Grind Batter: Grind the soaked urad dal into a smooth paste. Then grind the rice into a slightly coarse batter. Combine both, add salt, and mix well.
3. Ferment Batter: Allow the batter to ferment overnight or for 8 hours in a warm place. The batter should rise and become light.
4. Steam Idlis: Grease idli molds with oil, pour the batter, and steam for 10-15 minutes in an idli steamer.
5. Serve: Serve hot with coconut chutney and sambar.

---

#### 6. **Tips**  
- Use leftover idlis to make masala idli or fry them for a snack.  
- Adjust fermentation time based on the climate. Warm weather speeds up fermentation.

---

#### 7. **Serving Suggestions**  
- Serve with sambar, coconut chutney, or tomato chutney.  
- Add a dollop of ghee on top for extra flavor.

---

#### 8. **Nutritional Information**  
- **Calories:** 120 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 22 g  
- **Fat:** 0.5 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",  # Extract dish name
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",  # Extract description
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",  # Extract ingredients
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",  # Extract preparation time
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",  # Extract cooking time
    "Total Time": r"Total Time:\*\* (.+?)\n",  # Extract total time
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",  # Extract how-to steps
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",  # Extract tips
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",  # Extract serving suggestions
    "Calories": r"Calories:\*\* (\d+)",  # Extract calories
    "Protein": r"Protein:\*\* ([\d.]+)",  # Extract protein
    "Fat": r"Fat:\*\* ([\d.]+)"  # Extract fat
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = np.nan  # If no match, assign NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or NaN
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": np.nan,
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Steamed Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": np.nan
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)
# Out:
#                                                 Name  \
# 0  Idli\n\n#### 2. **Description**  \n> Idli is a...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Idli is a soft, fluffy steamed rice cake that ...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Healthy, Gluten-Free        5  ...        4
#
#   Cholesterol Sodium Saturated Fat  Sugar          Type  \
# 0           0      0             0      0  Steamed Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Idli\n\n#### 2. **Description**  \n> Idli is a...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Idli is a soft, fluffy steamed rice cake that ...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Healthy, Gluten-Free        5  ...        4
#
#   Cholesterol Sodium Saturated Fat  Sugar          Type  \
# 0           0      0             0      0  Steamed Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
df.to_csv("food_data.csv", index=False)

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Dosa

#### 2. **Description**  
> Dosa is a popular South Indian dish made from fermented rice and lentil batter. Known for its thin, crispy texture, dosa is a nutritious and versatile dish often enjoyed for breakfast or as a light meal.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups rice
  - 1/2 cup urad dal
  - 1/2 tsp fenugreek seeds
  - Water (as required)
  - Salt (to taste)
- **For Cooking:**
  - Oil or ghee (for greasing and drizzling)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Wash the rice, urad dal, and fenugreek seeds thoroughly. Soak them together in water for 6-8 hours.  
2. Drain the soaked ingredients and grind into a smooth batter, adding water as needed. Add salt and mix well.  
3. Cover and ferment the batter overnight or for 8 hours until it rises and becomes light and airy.  
4. Heat a non-stick pan or tava on medium heat. Grease it lightly with oil or ghee.  
5. Pour a ladleful of batter in the center of the pan and spread it in a circular motion to form a thin layer. Drizzle oil or ghee around the edges.  
6. Cook until the dosa turns golden brown and the edges lift. Flip if desired, cook for a few seconds, and serve hot.  

---

#### 6. **Tips**  
- Add a tablespoon of semolina to the batter for extra crispiness.  
- Always use a hot, well-greased pan to prevent sticking.  

---

#### 7. **Serving Suggestions**  
- Serve dosa with coconut chutney, sambar, and tomato chutney.  
- For masala dosa, fill the center with a spiced potato mixture before folding.  

---

#### 8. **Nutritional Information**  
- **Calories:** 160 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 30 g  
- **Fat:** 1 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = np.nan  # If no match, assign NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or NaN
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": np.nan,
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Steamed Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": np.nan
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Dosa\n\n#### 2. **Description**  \n> Dosa is a...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Dosa is a popular South Indian dish made from ...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Healthy, Gluten-Free        5  ...        5
#
#   Cholesterol Sodium Saturated Fat  Sugar          Type  \
# 0           0      0             0      0  Steamed Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Dosa\n\n#### 2. **Description**  \n> Dosa is a...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Dosa is a popular South Indian dish made from ...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Healthy, Gluten-Free        5  ...        5
#
#   Cholesterol Sodium Saturated Fat  Sugar          Type  \
# 0           0      0             0      0  Steamed Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Uttapam

#### 2. **Description**  
> Uttapam is a thick, soft, and savory pancake made from fermented rice and lentil batter. It is a popular South Indian breakfast dish that is often topped with vegetables, making it both nutritious and delicious.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups rice
  - 1/2 cup urad dal
  - 1/4 tsp fenugreek seeds
  - Water (as required)
  - Salt (to taste)
- **For Toppings:**
  - 1/2 cup finely chopped onions
  - 1/4 cup finely chopped tomatoes
  - 1/4 cup grated carrots
  - 2 tbsp chopped coriander leaves
  - 1-2 green chilies, finely chopped
- **For Cooking:**
  - Oil or ghee (for greasing and drizzling)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Wash and soak rice, urad dal, and fenugreek seeds together for 6-8 hours.  
2. Drain and grind the ingredients into a smooth batter, adding water as needed. Add salt and mix well.  
3. Ferment the batter overnight or for 8 hours until it becomes light and fluffy.  
4. Heat a non-stick pan or tava on medium heat. Grease lightly with oil or ghee.  
5. Pour a ladleful of batter in the center of the pan and spread into a thick pancake.  
6. Sprinkle chopped onions, tomatoes, carrots, coriander leaves, and green chilies over the batter.  
7. Drizzle oil or ghee around the edges. Cook on one side until golden brown and the toppings are cooked. Flip if needed and cook for another minute.  
8. Serve hot with coconut chutney or sambar.  

---

#### 6. **Tips**  
- Use a well-fermented batter for the best results.  
- Experiment with toppings such as cheese, grated beetroot, or sweet corn.  

---

#### 7. **Serving Suggestions**  
- Serve uttapam with coconut chutney, tomato chutney, or sambar.  
- Add a dollop of butter on top for extra flavor.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 30 g  
- **Fat:** 3 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = np.nan  # If no match, assign NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or NaN
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": np.nan,
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Savory Pancake",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": np.nan
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Uttapam\n\n#### 2. **Description**  \n> Uttapa...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Uttapam is a thick, soft, and savory pancake m...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Healthy, Gluten-Free        5  ...        6
#
#   Cholesterol Sodium Saturated Fat  Sugar            Type  \
# 0           0      0             0      0  Savory Pancake
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Uttapam\n\n#### 2. **Description**  \n> Uttapa...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Uttapam is a thick, soft, and savory pancake m...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Healthy, Gluten-Free        5  ...        6
#
#   Cholesterol Sodium Saturated Fat  Sugar            Type  \
# 0           0      0             0      0  Savory Pancake
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Upma

#### 2. **Description**  
> Upma is a savory, flavorful South Indian breakfast dish made from semolina (rava). It is quick to prepare, highly customizable, and perfect for busy mornings.

---

#### 3. **Ingredients**  
- **For Upma:**
  - 1 cup semolina (rava)
  - 2 cups water
  - 1/2 cup chopped vegetables (carrots, beans, peas)
  - 1/2 tsp mustard seeds
  - 1 tsp urad dal
  - 1 tsp chana dal
  - 2-3 green chilies, finely chopped
  - A few curry leaves
  - 1 small onion, finely chopped
  - 2 tbsp oil or ghee
  - Salt (to taste)
  - Fresh coriander leaves (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 10-15 minutes  
- **Total Time:** ~25 minutes  

---

#### 5. **How to Prepare**  
1. Dry Roast Semolina: Heat a pan and dry roast the semolina on low-medium heat until it turns light golden and aromatic. Keep it aside.  
2. Heat Oil: In the same pan, heat oil or ghee. Add mustard seeds and let them splutter.  
3. Add Lentils and Spices: Add urad dal, chana dal, green chilies, curry leaves, and chopped onions. Sauté until onions turn translucent.  
4. Cook Vegetables: Add chopped vegetables and sauté for a few minutes. Pour in the water, add salt, and let it come to a boil.  
5. Add Semolina: Gradually add the roasted semolina while continuously stirring to avoid lumps. Reduce the heat to low.  
6. Cook: Cover and cook for 2-3 minutes, stirring occasionally, until the semolina absorbs the water and reaches a soft consistency.  
7. Garnish and Serve: Garnish with fresh coriander leaves and serve hot.

---

#### 6. **Tips**  
- You can add cashews for added crunch and flavor.  
- Adjust the water quantity depending on the desired consistency.  

---

#### 7. **Serving Suggestions**  
- Serve upma hot with coconut chutney or pickle.  
- A squeeze of lemon adds a refreshing tanginess.

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 36 g  
- **Fat:** 4 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = np.nan  # If no match, assign NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or NaN
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": np.nan,
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Quick and Nutritious",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Stovetop Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": np.nan
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Upma\n\n#### 2. **Description**  \n> Upma is a...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Upma is a savory, flavorful South Indian break...                 NaN
#
#    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0    NaN  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ...  Protein  \
# 0               False  Quick and Nutritious        5  ...        6
#
#   Cholesterol Sodium Saturated Fat  Sugar           Type  \
# 0           0      0             0      0  Stovetop Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Pongal

#### 2. **Description**  
> Pongal is a traditional South Indian dish made with rice, lentils, and ghee. Often prepared as an offering during festivals, this hearty dish is a comfort food favorite for breakfast or special occasions.

---

#### 3. **Ingredients**  
- **For Pongal:**
  - 1 cup rice
  - 1/2 cup moong dal
  - 1/2 tsp black pepper (crushed)
  - 1/4 tsp cumin seeds
  - A pinch of asafoetida
  - Salt (to taste)
  - 2 tbsp ghee
  - 10-12 cashews (optional)
- **For Cooking:**
  - 4 cups water

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 25-30 minutes  
- **Total Time:** 40 minutes  

---

#### 5. **How to Prepare**  
1. Rinse the rice and moong dal under running water.  
2. Heat a pressure cooker on medium heat. Add the rinsed rice and dal, along with water, and cook for 4-5 whistles or until soft and mushy.  
3. In a small pan, heat ghee and fry the cashews until golden. Add black pepper, cumin seeds, and asafoetida, and fry for a few seconds.  
4. Pour the tempering over the cooked rice and dal mixture. Mix well and adjust salt as needed.  
5. Serve hot, garnished with additional ghee for flavor.

---

#### 6. **Tips**  
- For a richer flavor, roast the moong dal before cooking.  
- Add a pinch of turmeric for a festive yellow color.  

---

#### 7. **Serving Suggestions**  
- Serve Pongal hot with coconut chutney or a dollop of tangy sambar.  
- Pair with papad for added crunch.  

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 34 g  
- **Fat:** 5 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Assign default empty string if a match isn't found

# Fill additional columns with default values
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "https://example.com/pongal.jpg",  # Placeholder for photo
    "Region": "South India",
    "Time of Eating (B)": True,  # Suitable for breakfast
    "Time of Eating (L)": True,  # Suitable for lunch
    "Time of Eating (D)": False,  # Not typically eaten for dinner
    "Food Type": "Healthy, Vegetarian",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 1,
    "Sugar": 0,
    "Type": "Rice Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast, Lunch",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "High Protein"
})

# Create a DataFrame with no null values
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Pongal\n\n#### 2. **Description**  \n> Pongal ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Pongal is a traditional South Indian dish made...
#
#                             Photo       Region  Time of Eating (B)  \
# 0  https://example.com/pongal.jpg  South India                True
#
#    Time of Eating (L)  Time of Eating (D)            Food Type  Ratings  ...  \
# 0                True               False  Healthy, Vegetarian        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0       6           0      0             1      0  Rice Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                   Breakfast, Lunch      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High Protein
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Pongal\n\n#### 2. **Description**  \n> Pongal ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Pongal is a traditional South Indian dish made...
#
#                             Photo       Region  Time of Eating (B)  \
# 0  https://example.com/pongal.jpg  South India                True
#
#    Time of Eating (L)  Time of Eating (D)            Food Type  Ratings  ...  \
# 0                True               False  Healthy, Vegetarian        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0       6           0      0             1      0  Rice Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                   Breakfast, Lunch      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High Protein
#
# ...

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Rava Idli

#### 2. **Description**  
> Rava Idli is a popular South Indian breakfast made with semolina, yogurt, and a few spices. This instant variation of idli is soft, fluffy, and perfect for a quick and wholesome meal.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup semolina (rava)
  - 1/2 cup yogurt (curd)
  - 1/2 tsp baking soda or Eno
  - Water (as required)
  - Salt (to taste)
- **For Tempering:**
  - 1 tsp mustard seeds
  - 1 tsp cumin seeds
  - A pinch of asafoetida
  - 1 tbsp oil or ghee
  - 1-2 green chilies, finely chopped
  - Few curry leaves
  - 2 tbsp grated carrot (optional)
- **For Steaming:**
  - Oil (for greasing the idli molds)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~35 minutes  

---

#### 5. **How to Prepare**  
1. Heat oil or ghee in a pan, add mustard seeds, cumin seeds, and let them splutter. Add asafoetida, chopped chilies, curry leaves, and grated carrot. Sauté for a minute.  
2. Add semolina to the pan and roast it on medium heat until it turns aromatic. Let it cool.  
3. Mix roasted semolina, yogurt, salt, and water to form a smooth batter. Let it rest for 10 minutes.  
4. Add baking soda or Eno to the batter just before steaming and mix gently.  
5. Grease idli molds with oil, pour the batter, and steam for 15-20 minutes in an idli steamer.  
6. Serve hot with coconut chutney and sambar.  

---

#### 6. **Tips**  
- Add chopped coriander leaves and grated coconut for additional flavor.  
- Use ghee for a richer taste.  

---

#### 7. **Serving Suggestions**  
- Serve Rava Idli with coconut chutney, sambar, or tomato chutney.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 28 g  
- **Fat:** 5 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not Available"  # Replace nulls with 'Not Available'

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Not Available",
    "Region": "South India",
    "Time of Eating (B)": True,
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Instant, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": "Low",
    "Saturated Fat": "Low",
    "Sugar": "Low",
    "Type": "Steamed Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Suitable for Muscle Gain"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Rava Idli\n\n#### 2. **Description**  \n> Rava...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Rava Idli is a popular South Indian breakfast ...      Not Available
#
#            Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Not Available  South India                True               False
#
#    Time of Eating (D)                      Food Type  Ratings  ... Protein  \
# 0               False  Healthy, Instant, Gluten-Free        5  ...       5
#
#   Cholesterol Sodium Saturated Fat  Sugar          Type  \
# 0           0    Low           Low    Low  Steamed Dish
#
#   Food Type (Veg/Non-Veg/Vegan)  \
# 0                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                         Breakfast      Diabetic Friendly
#
#      Category (Muscle Gain)
# 0  Suitable for Muscle Gain
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Rava Idli\n\n#### 2. **Description**  \n> Rava...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Rava Idli is a popular South Indian breakfast ...      Not Available
#
#            Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Not Available  South India                True               False
#
#    Time of Eating (D)                      Food Type  Ratings  ... Protein  \
# 0               False  Healthy, Instant, Gluten-Free        5  ...       5
#
#   Cholesterol Sodium Saturated Fat  Sugar          Type  \
# 0           0    Low           Low    Low  Steamed Dish
#
#   Food Type (Veg/Non-Veg/Vegan)  \
# 0                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                         Breakfast      Diabetic Friendly
#
#      Category (Muscle Gain)
# 0  Suitable for Muscle Gain
#
# ...

# %%
import pandas as pd
import re

# Recipe text for Appam
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Appam

#### 2. **Description**  
> Appam is a lacy, soft-centered rice pancake popular in Kerala, India. It is made from fermented rice and coconut batter, usually served with coconut milk or vegetable stew.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups raw rice
  - 1/2 cup grated coconut
  - 1 tsp sugar
  - 1/2 tsp dry yeast
  - Salt (to taste)
  - Water (as required)
- **For Cooking:**
  - Oil or ghee (for greasing the pan)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (soaking and fermenting)  
- **Cooking Time:** 15 minutes  
- **Total Time:** ~8 hours 15 minutes  

---

#### 5. **How to Prepare**  
1. Soak the raw rice in water for 6 hours.  
2. Grind the soaked rice with grated coconut into a smooth batter using water as needed.  
3. Dissolve dry yeast and sugar in warm water and add to the batter. Mix well and allow it to ferment for 2 hours in a warm place.  
4. Add salt and mix the batter. The batter should have a pouring consistency.  
5. Heat an appam pan on medium heat. Grease it lightly, pour a ladle of batter, and swirl the pan to spread the batter. Cover and cook until the edges are crisp and the center is cooked.  
6. Serve warm with coconut milk, vegetable stew, or any curry of your choice.  

---

#### 6. **Tips**  
- Use fresh coconut for the best flavor.  
- Adjust the consistency of the batter with water before cooking.  

---

#### 7. **Serving Suggestions**  
- Best served with sweetened coconut milk, vegetable stew, or Kerala-style egg curry.

---

#### 8. **Nutritional Information**  
- **Calories:** 110 kcal  
- **Protein:** 3 g  
- **Carbohydrates:** 20 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else ""  # Assign empty string if no match

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with appropriate values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "appam.jpg",  # Placeholder for an image URL or path
    "Region": "Kerala, South India",
    "Time of Eating (B)": True,  # Typically eaten as breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 2,  # mg (example value)
    "Saturated Fat": 1,  # g (example value)
    "Sugar": 1,  # g (example value)
    "Type": "Pancake",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Moderate"
})

# Ensure no null values exist
for key in columns:
    if key not in extracted_data or extracted_data[key] in [None, "", np.nan]:
        extracted_data[key] = "N/A"  # Fill missing fields with 'N/A'

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Appam\n\n#### 2. **Description**  \n> Appam is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Appam is a lacy, soft-centered rice pancake po...                N/A
#
#        Photo               Region  Time of Eating (B)  Time of Eating (L)  \
# 0  appam.jpg  Kerala, South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Healthy, Gluten-Free        5  ...       3           0
#
#   Sodium Saturated Fat  Sugar     Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      2             1      1  Pancake                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0               Moderate
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Appam\n\n#### 2. **Description**  \n> Appam is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Appam is a lacy, soft-centered rice pancake po...                N/A
#
#        Photo               Region  Time of Eating (B)  Time of Eating (L)  \
# 0  appam.jpg  Kerala, South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Healthy, Gluten-Free        5  ...       3           0
#
#   Sodium Saturated Fat  Sugar     Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      2             1      1  Pancake                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0               Moderate
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Puttu
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Puttu

#### 2. **Description**  
> Puttu is a traditional steamed rice flour and coconut dish from Kerala, usually served for breakfast. This healthy and gluten-free dish pairs perfectly with kadala curry or ripe bananas.

---

#### 3. **Ingredients**  
- **For Puttu:**
  - 2 cups rice flour
  - 1 cup freshly grated coconut
  - 1/4 tsp salt
  - Water (as required)
- **For Cooking:**
  - Puttu maker or steaming vessel

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 15 minutes  
- **Total Time:** 25 minutes  

---

#### 5. **How to Prepare**  
1. Mix Ingredients: In a bowl, mix rice flour and salt. Add water gradually to form a crumbly texture (similar to wet sand). Ensure it is moist but not sticky.  
2. Layer Ingredients: In a puttu maker, layer grated coconut and rice flour alternately, starting and ending with coconut.  
3. Steam: Attach the puttu maker to a steaming vessel and steam for 10-15 minutes until cooked and aromatic.  
4. Serve: Serve hot with kadala curry, bananas, or melted jaggery.  

---

#### 6. **Tips**  
- To add flavor, roast the rice flour lightly before using.  
- Replace rice flour with ragi or wheat flour for variations.  

---

#### 7. **Serving Suggestions**  
- Serve with kadala curry (black chickpea curry), ripe bananas, or drizzle with melted jaggery.  
- Add a dollop of ghee for enhanced flavor.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 38 g  
- **Fat:** 3 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Not Available"  # Assign default value to avoid null

# Define DataFrame columns and assign extracted/default values
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with non-null default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Image not available",
    "Region": "Kerala",
    "Time of Eating (B)": True,
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Gluten-Free, Healthy",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 1,
    "Sugar": 0,
    "Type": "Steamed Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Not Recommended"
})

# Convert the data to a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Puttu\n\n#### 2. **Description**  \n> Puttu is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Puttu is a traditional steamed rice flour and ...      Not Available
#
#                  Photo  Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Image not available  Kerala                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Gluten-Free, Healthy        5  ...       4           0
#
#   Sodium Saturated Fat  Sugar          Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0             1      0  Steamed Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Not Recommended
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Puttu\n\n#### 2. **Description**  \n> Puttu is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Puttu is a traditional steamed rice flour and ...      Not Available
#
#                  Photo  Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Image not available  Kerala                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Gluten-Free, Healthy        5  ...       4           0
#
#   Sodium Saturated Fat  Sugar          Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0             1      0  Steamed Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Not Recommended
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Neer Dosa

#### 2. **Description**  
> Neer Dosa is a soft, thin, and smooth rice crepe from the coastal region of Karnataka. It is known for its delicate texture and light taste, often served with coconut chutney and sambar.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 1/2 cups rice
  - 1/4 cup soaked urad dal
  - 1/4 tsp cumin seeds
  - Salt (to taste)
  - Water (as required)
- **For Cooking:**
  - Oil or ghee (for greasing the pan)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 3-4 hours (for soaking rice and urad dal)  
- **Cooking Time:** 1-2 minutes per dosa  
- **Total Time:** ~4 hours 10 minutes  

---

#### 5. **How to Prepare**  
1. Wash the rice and urad dal thoroughly and soak them in water for 3 hours.  
2. After soaking, grind them together into a smooth, watery batter. Add salt and mix well.  
3. Heat a non-stick pan or tava. Grease lightly with oil or ghee.  
4. Pour a ladleful of the batter onto the hot pan and spread it gently to form a thin, smooth layer.  
5. Cook for 1-2 minutes until the edges start lifting and the dosa is cooked through. Do not flip it like a regular dosa; it should remain soft and thin.  
6. Serve hot with coconut chutney, sambar, or any chutney of your choice.

---

#### 6. **Tips**  
- The batter should be runny; adjust the consistency by adding water to the batter if it’s too thick.  
- Neer dosa should be eaten fresh to enjoy its soft texture.  

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney, sambar, or tomato chutney.  
- It can also be served with a vegetable curry for a wholesome meal.

---

#### 8. **Nutritional Information**  
- **Calories:** 130 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 25 g  
- **Fat:** 1 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Not Provided"  # If no match, assign "Not Provided"

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or provided data
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Not Provided",
    "Region": "Karnataka",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Rice Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Not Provided"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Neer Dosa\n\n#### 2. **Description**  \n> Neer...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Neer Dosa is a soft, thin, and smooth rice cre...       Not Provided
#
#           Photo     Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Not Provided  Karnataka                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Healthy, Gluten-Free        5  ...       4           0
#
#   Sodium Saturated Fat  Sugar       Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0             0      0  Rice Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           Not Provided
#
# [1 rows x 23 columns]

# %%
df[df["Name"]=="Appam"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df[df["Name"]=="Appam"]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Kanchipuram Idli

#### 2. **Description**  
> Kanchipuram Idli is a savory, spiced version of the traditional idli, originating from the town of Kanchipuram in Tamil Nadu. It's made with a combination of rice, urad dal, spices, and herbs, giving it a unique flavor compared to the regular idli.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup rice
  - 1/4 cup urad dal
  - 1/4 cup moong dal
  - 1 tsp black pepper
  - 1/2 tsp cumin seeds
  - 1/4 tsp asafoetida (hing)
  - 1/2 tsp ginger (grated)
  - 1-2 green chilies (chopped)
  - A few curry leaves (chopped)
  - Salt (to taste)
  - Water (as required)
- **For Steaming:**
  - Oil (for greasing idli molds)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 6-8 hours (for soaking and fermenting)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Soak the rice, urad dal, and moong dal in water for 6-8 hours.  
2. Grind the soaked ingredients into a smooth batter using water as needed. Add salt, ginger, green chilies, and curry leaves to the batter, mixing well.  
3. Heat a little oil in a pan and add cumin seeds, black pepper, and asafoetida. Stir-fry for a minute and add this tempering to the batter.  
4. Let the batter ferment for 6-8 hours or overnight in a warm place.  
5. Grease idli molds with oil, pour the batter into the molds, and steam for 15-20 minutes.  
6. Serve hot with coconut chutney or sambar.  

---

#### 6. **Tips**  
- For extra flavor, you can add chopped cashews or roasted cumin powder to the batter.  
- Ensure that the batter ferments well for soft idlis.

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney, sambar, or tomato chutney.  
- Kanchipuram Idli is delicious when served with a drizzle of ghee on top.

---

#### 8. **Nutritional Information**  
- **Calories:** 130 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 25 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # If no match, assign an empty string

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Spicy",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Steamed Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Kanchipuram Idli\n\n#### 2. **Description**  \...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Kanchipuram Idli is a savory, spiced version o...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Healthy, Spicy        5  ...       5           0      0             0
#
#    Sugar          Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Steamed Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Kanchipuram Idli\n\n#### 2. **Description**  \...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Kanchipuram Idli is a savory, spiced version o...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Healthy, Spicy        5  ...       5           0      0             0
#
#    Sugar          Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Steamed Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Masala Dosa
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Masala Dosa

#### 2. **Description**  
> Masala Dosa is a variation of the traditional dosa that features a flavorful spiced potato filling. A popular breakfast and street food in South India, this crispy dosa is often paired with chutneys and sambar.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups rice
  - 1/2 cup urad dal
  - 1/2 tsp fenugreek seeds
  - Water (as required)
  - Salt (to taste)
- **For Filling:**
  - 3 medium potatoes (boiled and mashed)
  - 1 onion (finely chopped)
  - 1-2 green chilies (finely chopped)
  - 1 tsp mustard seeds
  - 1/2 tsp turmeric powder
  - 1/2 tsp cumin seeds
  - A few curry leaves
  - 1 tbsp oil
  - Salt (to taste)
- **For Cooking:**
  - Oil or ghee (for greasing and drizzling)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 20-25 minutes  
- **Total Time:** ~8 hours 25 minutes  

---

#### 5. **How to Prepare**  
1. Wash the rice, urad dal, and fenugreek seeds thoroughly. Soak them together in water for 6-8 hours.  
2. Drain the soaked ingredients and grind into a smooth batter, adding water as needed. Add salt and mix well.  
3. Cover and ferment the batter overnight or for 8 hours until it rises and becomes light and airy.  
4. For the filling, heat oil in a pan, add mustard seeds, cumin seeds, and curry leaves. Once they splutter, add chopped onions and green chilies. Cook until the onions turn golden brown.  
5. Add turmeric powder and mashed potatoes. Stir well to mix the spices and seasonings. Cook for 5-7 minutes. Set aside.  
6. Heat a non-stick pan or tava on medium heat. Grease it lightly with oil or ghee.  
7. Pour a ladleful of batter in the center of the pan and spread it in a circular motion to form a thin layer. Drizzle oil or ghee around the edges.  
8. Cook until the dosa turns golden brown and the edges lift. Place a portion of the potato filling in the center of the dosa and fold it over.  
9. Serve hot with coconut chutney and sambar.  

---

#### 6. **Tips**  
- You can use leftover dosa batter for making masala dosa.
- Ensure that the pan is hot before spreading the batter to achieve crispiness.

---

#### 7. **Serving Suggestions**  
- Serve masala dosa with sambar, coconut chutney, or tomato chutney.
- Add a dollop of ghee on top for extra flavor.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 35 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Not Available"  # If no match, assign a default string

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or specific entries
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Not Available",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Fried/Grilled",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Not Applicable"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Masala Dosa\n\n#### 2. **Description**  \n> Ma...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Masala Dosa is a variation of the traditional ...      Not Available
#
#            Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Not Available  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Healthy, Gluten-Free        5  ...       5           0
#
#   Sodium Saturated Fat  Sugar           Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0             0      0  Fried/Grilled                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0         Not Applicable
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Masala Dosa\n\n#### 2. **Description**  \n> Ma...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Masala Dosa is a variation of the traditional ...      Not Available
#
#            Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Not Available  South India                True               False
#
#    Time of Eating (D)             Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Healthy, Gluten-Free        5  ...       5           0
#
#   Sodium Saturated Fat  Sugar           Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0             0      0  Fried/Grilled                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0         Not Applicable
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Onion Uttapam
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Onion Uttapam

#### 2. **Description**  
> Onion Uttapam is a savory South Indian pancake made from fermented dosa batter, topped with a variety of vegetables. The crispy outer layer with a soft and fluffy inside makes it a popular breakfast dish, served with chutneys and sambar.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups rice
  - 1/2 cup urad dal
  - 1/2 tsp fenugreek seeds
  - Water (as required)
  - Salt (to taste)
- **For Topping:**
  - 1 large onion, finely chopped
  - 1 green chili, finely chopped
  - Fresh coriander leaves, chopped
  - 1 tbsp oil or ghee (for cooking)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 10 minutes per uttapam  
- **Total Time:** ~8 hours 10 minutes  

---

#### 5. **How to Prepare**  
1. Soak the rice, urad dal, and fenugreek seeds in water for 6-8 hours. Drain and grind them into a smooth batter. Add salt and mix well.  
2. Let the batter ferment for 8 hours or overnight until it rises.  
3. Heat a non-stick pan or griddle on medium heat. Grease with a little oil or ghee.  
4. Pour a ladleful of batter onto the pan and spread into a thick circle.  
5. Immediately sprinkle chopped onions, green chilies, and coriander leaves on top of the batter.  
6. Drizzle oil or ghee along the edges and cook until the underside turns golden brown.  
7. Flip the uttapam if desired and cook the other side for a minute.  
8. Serve hot with coconut chutney, sambar, or tomato chutney.

---

#### 6. **Tips**  
- You can add other toppings like tomatoes, bell peppers, or even cheese.  
- If you prefer crispy uttapam, spread the batter thinner and use more oil.  

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney and sambar.  
- Can also be served with tomato chutney or a yogurt-based dip.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 35 g  
- **Fat:** 4 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Assign empty string for missing values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or placeholders
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",  # Can be left empty or filled with a URL if available
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Vegan",
    "Ratings": 4,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Pan-fried",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""  # Not provided in the text
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Onion Uttapam\n\n#### 2. **Description**  \n> ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Onion Uttapam is a savory South Indian pancake...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Healthy, Vegan        4  ...       5           0      0             0
#
#    Sugar       Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Pan-fried                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Onion Uttapam\n\n#### 2. **Description**  \n> ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Onion Uttapam is a savory South Indian pancake...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Healthy, Vegan        4  ...       5           0      0             0
#
#    Sugar       Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Pan-fried                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Semiya Upma (Vermicelli Upma)

#### 2. **Description**  
> Semiya Upma is a savory, spiced dish made from roasted semiya (vermicelli), commonly eaten for breakfast in South India. It is a quick and easy dish made with minimal ingredients and is a perfect option for busy mornings.

---

#### 3. **Ingredients**  
- **For Cooking:**
  - 1 cup semiya (vermicelli)
  - 1 tablespoon oil
  - 1 teaspoon mustard seeds
  - 1/2 teaspoon cumin seeds
  - 1/4 teaspoon turmeric powder
  - 1/4 teaspoon red chili powder
  - 1/2 cup finely chopped onions
  - 1/2 cup mixed vegetables (carrot, peas, beans)
  - 2 green chilies, slit
  - 1 teaspoon grated ginger
  - Salt (to taste)
  - 2 cups water
  - Fresh coriander leaves (for garnishing)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 10 minutes  
- **Total Time:** ~20 minutes  

---

#### 5. **How to Prepare**  
1. Roast the semiya in a dry pan on low heat for 3-4 minutes until it turns golden brown. Set aside.  
2. Heat oil in a pan and add mustard seeds and cumin seeds. Once they splutter, add turmeric powder, red chili powder, and sauté for a few seconds.  
3. Add chopped onions and sauté until translucent. Then add green chilies, grated ginger, and mixed vegetables. Cook for 3-4 minutes until the vegetables soften.  
4. Add 2 cups of water and bring it to a boil. Add salt to taste.  
5. Once the water boils, add the roasted semiya, stirring to mix. Reduce the heat to low, cover, and cook for 5-7 minutes until the semiya absorbs all the water and softens.  
6. Garnish with fresh coriander leaves and serve hot.

---

#### 6. **Tips**  
- You can use roasted semiya or roast fresh semiya yourself.  
- Add a squeeze of lemon juice to enhance the flavor.  

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney or pickles for added flavor.  
- Can be accompanied by yogurt or a bowl of sambar.

---

#### 8. **Nutritional Information**  
- **Calories:** 210 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 40 g  
- **Fat:** 6 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Assign empty string if no match is found

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",  # No photo included in this recipe
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Light, Healthy",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Stir-fried Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Semiya Upma (Vermicelli Upma)\n\n#### 2. **Des...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Semiya Upma is a savory, spiced dish made from...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Light, Healthy        5  ...       5           0      0             0
#
#    Sugar             Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Stir-fried Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Semiya Upma (Vermicelli Upma)\n\n#### 2. **Des...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Semiya Upma is a savory, spiced dish made from...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Light, Healthy        5  ...       5           0      0             0
#
#    Sugar             Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Stir-fried Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Adai
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Adai

#### 2. **Description**  
> Adai is a popular savory pancake from South India, made from a mixture of rice and various lentils. It is a high-protein, nutritious dish often enjoyed for breakfast or dinner, served with chutneys and sambar.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup rice
  - 1/4 cup toor dal
  - 1/4 cup chana dal
  - 1/4 cup moong dal
  - 1-2 dried red chilies
  - 1/4 tsp cumin seeds
  - 1/4 tsp black pepper
  - 1 small piece of ginger
  - Salt (to taste)
  - Water (as needed)
- **For Cooking:**
  - Oil (for frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 5-6 hours (for soaking)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~6 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Soak the rice and lentils separately for 5-6 hours or overnight.  
2. Drain the soaked rice and lentils, then grind them together along with dried red chilies, cumin seeds, black pepper, and ginger into a coarse batter.  
3. Add salt to the batter and adjust the consistency with water.  
4. Heat a tawa or pan and drizzle a little oil. Pour a ladleful of batter, spread it out into a thick circle, and cook on medium heat.  
5. Flip the adai to cook both sides until crispy and golden brown.  
6. Serve hot with coconut chutney or sambar.

---

#### 6. **Tips**  
- Add finely chopped vegetables like onions, carrots, and spinach to the batter for a variation.  
- You can also add a pinch of asafoetida for extra flavor.

---

#### 7. **Serving Suggestions**  
- Serve adai with coconut chutney, sambar, or a spicy onion chutney.  
- For a lighter meal, enjoy it with buttermilk on the side.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 9 g  
- **Carbohydrates:** 30 g  
- **Fat:** 4 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        # In case of no match, fill with some default data instead of NaN
        extracted_data[key] = "N/A"

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or custom values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "N/A",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Could also be a dinner item
    "Food Type": "Healthy, Gluten-Free, Protein-rich",
    "Ratings": 4,  # Adjusted to be realistic
    "Cholesterol": 0,
    "Sodium": 20,  # Example sodium amount
    "Saturated Fat": 0.5,  # Example value
    "Sugar": 0,  # Usually minimal in adai
    "Type": "Savory Pancake",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "High-Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Adai\n\n#### 2. **Description**  \n> Adai is a...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Adai is a popular savory pancake from South In...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False                True
#
#                             Food Type  Ratings  ... Protein Cholesterol  \
# 0  Healthy, Gluten-Free, Protein-rich        4  ...       9           0
#
#   Sodium Saturated Fat  Sugar            Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0     20           0.5      0  Savory Pancake                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High-Protein
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Adai\n\n#### 2. **Description**  \n> Adai is a...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Adai is a popular savory pancake from South In...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False                True
#
#                             Food Type  Ratings  ... Protein Cholesterol  \
# 0  Healthy, Gluten-Free, Protein-rich        4  ...       9           0
#
#   Sodium Saturated Fat  Sugar            Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0     20           0.5      0  Savory Pancake                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High-Protein
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Ragi Dosa

#### 2. **Description**  
> Ragi Dosa is a healthier variation of the traditional dosa, made with ragi (finger millet) flour, providing a boost of iron, calcium, and fiber. This dish is an ideal choice for breakfast and is especially popular in South India.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup ragi flour
  - 1/2 cup rice flour
  - 1/4 cup urad dal
  - 1/4 cup fenugreek seeds
  - Salt (to taste)
  - Water (as required)
- **For Cooking:**
  - Oil or ghee (for greasing and drizzling)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Wash the urad dal and fenugreek seeds thoroughly. Soak them in water for 6-8 hours.
2. Drain the soaked ingredients and grind them into a smooth batter. Add ragi flour, rice flour, salt, and water to make a smooth, pourable consistency.
3. Allow the batter to ferment for 8 hours or overnight in a warm place. The batter should become airy and light.
4. Heat a non-stick pan or tava on medium heat. Grease it lightly with oil or ghee.
5. Pour a ladleful of batter in the center of the pan and spread it in a circular motion to form a thin layer. Drizzle oil or ghee around the edges.
6. Cook until the dosa turns golden brown and crispy. Flip if desired, cook for a few more seconds, and serve hot.

---

#### 6. **Tips**  
- Adjust the consistency of the batter with water if it's too thick.  
- You can add chopped onions or green chilies to the batter for extra flavor.

---

#### 7. **Serving Suggestions**  
- Serve Ragi Dosa with coconut chutney, sambar, or tomato chutney.  
- Enjoy it as a snack or a healthy breakfast.

---

#### 8. **Nutritional Information**  
- **Calories:** 150 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 28 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Empty string instead of NaN to ensure no null values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings (for non-null values)
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Pan-fried Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Ragi Dosa\n\n#### 2. **Description**  \n> Ragi...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Ragi Dosa is a healthier variation of the trad...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Healthy, Gluten-Free        5  ...       6           0      0
#
#   Saturated Fat  Sugar            Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             0      0  Pan-fried Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Ragi Dosa\n\n#### 2. **Description**  \n> Ragi...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Ragi Dosa is a healthier variation of the trad...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Healthy, Gluten-Free        5  ...       6           0      0
#
#   Saturated Fat  Sugar            Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             0      0  Pan-fried Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Wheat Dosa

#### 2. **Description**  
> Wheat Dosa is a healthier variation of the traditional dosa made with whole wheat flour. This version is quick and easy to prepare, yet maintains the crispy texture, making it an excellent option for breakfast or dinner.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups whole wheat flour
  - 1/2 cup rice flour
  - 1/4 tsp cumin seeds
  - 1/2 tsp salt
  - Water (as required)
- **For Cooking:**
  - Oil or ghee (for greasing)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15-20 minutes  
- **Cooking Time:** 10-12 minutes  
- **Total Time:** ~30 minutes  

---

#### 5. **How to Prepare**  
1. In a bowl, mix together whole wheat flour, rice flour, cumin seeds, and salt.  
2. Slowly add water, whisking continuously to form a smooth, pourable batter.  
3. Heat a non-stick pan or tava and grease lightly with oil or ghee.  
4. Pour a ladleful of the batter onto the center of the pan and spread it in a circular motion to form a thin layer.  
5. Drizzle a little oil or ghee around the edges of the dosa and cook until golden brown and crispy on both sides.  
6. Serve hot with chutney or sambar.

---

#### 6. **Tips**  
- Add finely chopped vegetables like onions, tomatoes, and carrots to the batter for added texture and flavor.  
- If the batter is too thick, add a bit more water to thin it out.

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney, sambar, or tomato chutney.  
- Enjoy it with a side of fresh salad or pickles.

---

#### 8. **Nutritional Information**  
- **Calories:** 140 kcal  
- **Protein:** 3 g  
- **Carbohydrates:** 28 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Ensure no null values, replace with empty strings

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or an empty string
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "",  # No photo value provided
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Whole Wheat",
    "Ratings": "5",
    "Cholesterol": "0",
    "Sodium": "0",
    "Saturated Fat": "0",
    "Sugar": "0",
    "Type": "Crispy Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Wheat Dosa\n\n#### 2. **Description**  \n> Whe...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Wheat Dosa is a healthier variation of the tra...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Healthy, Whole Wheat       5  ...       3           0      0             0
#
#   Sugar         Type Food Type (Veg/Non-Veg/Vegan)  \
# 0     0  Crispy Dish                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                         Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Wheat Dosa\n\n#### 2. **Description**  \n> Whe...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Wheat Dosa is a healthier variation of the tra...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Healthy, Whole Wheat       5  ...       3           0      0             0
#
#   Sugar         Type Food Type (Veg/Non-Veg/Vegan)  \
# 0     0  Crispy Dish                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                         Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Thatte Idli
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Thatte Idli

#### 2. **Description**  
> Thatte Idli is a large, flat version of the traditional South Indian Idli. Known for its soft and fluffy texture, this dish is served with chutney and sambar, and is perfect for breakfast.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups rice
  - 1 cup urad dal
  - 1 tsp fenugreek seeds
  - Water (as needed)
  - Salt (to taste)
- **For Steaming:**
  - Oil (for greasing the plates)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 15 minutes  
- **Total Time:** ~8 hours 15 minutes  

---

#### 5. **How to Prepare**  
1. Wash the rice and urad dal thoroughly and soak them together with fenugreek seeds for 6-8 hours.  
2. Drain and grind the soaked mixture into a smooth batter, adding water as needed. Add salt and mix well.  
3. Let the batter ferment overnight or for 8 hours in a warm place.  
4. Grease large, flat idli plates with oil and pour the batter onto them.  
5. Steam for about 10-15 minutes until the Thatte Idlis are cooked and fluffy.  
6. Serve hot with coconut chutney and sambar.

---

#### 6. **Tips**  
- Use idli plates with a flat surface for the characteristic shape of Thatte Idli.  
- If you don’t have a steamer, you can also steam the batter in a large pot with a lid.

---

#### 7. **Serving Suggestions**  
- Serve with sambar, coconut chutney, and tomato chutney.  
- Pair with a hot cup of filter coffee for a traditional South Indian breakfast.

---

#### 8. **Nutritional Information**  
- **Calories:** 140 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 30 g  
- **Fat:** 1 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "N/A"  # Replace missing with 'N/A'

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", "N/A"),
    "Photo": "N/A",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Steamed Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "N/A"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Thatte Idli\n\n#### 2. **Description**  \n> Th...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Thatte Idli is a large, flat version of the tr...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Healthy, Gluten-Free        5  ...       5           0      0
#
#   Saturated Fat  Sugar          Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             0      0  Steamed Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    N/A
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Thatte Idli\n\n#### 2. **Description**  \n> Th...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Thatte Idli is a large, flat version of the tr...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Healthy, Gluten-Free        5  ...       5           0      0
#
#   Saturated Fat  Sugar          Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             0      0  Steamed Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    N/A
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Kal Dosa
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Kal Dosa

#### 2. **Description**  
> Kal Dosa is a popular variation of the regular dosa, made with a slightly thicker batter and often served with spicy chutneys or a rich lentil soup. It originates from the south of India and is a great option for breakfast or dinner.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1.5 cups rice
  - 1/2 cup urad dal
  - 1/4 tsp fenugreek seeds
  - 1 tsp cumin seeds
  - Water (as needed)
  - Salt (to taste)
- **For Cooking:**
  - Oil or ghee (for greasing)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking and fermenting)  
- **Cooking Time:** 20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Rinse rice, urad dal, and fenugreek seeds in plenty of water. Soak them in separate bowls for 6-8 hours.  
2. Drain the ingredients and grind them separately. Rice should be ground to a coarse batter, while urad dal should be ground into a fine paste.  
3. Combine the batters, add salt, and let the batter ferment in a warm place for 8 hours or overnight.  
4. Heat a heavy griddle and grease lightly with ghee or oil.  
5. Pour a ladle of batter and spread it into a thick circle, allowing the edges to crisp up slightly.  
6. Cook for 2-3 minutes until the bottom is golden brown, then flip and cook for another minute.  
7. Serve hot with sambar or coconut chutney.

---

#### 6. **Tips**  
- The thickness of Kal Dosa gives it a slightly soft center, different from the regular crispy dosa.  
- For a richer flavor, use ghee to cook the dosa.

---

#### 7. **Serving Suggestions**  
- Serve Kal Dosa with spicy sambar or fresh coconut chutney.  
- You can also add a filling of potatoes for a masala dosa variant.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 35 g  
- **Fat:** 3 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Replace NaN with empty string to avoid nulls

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings to avoid nulls
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": "True",  # Breakfast option
    "Time of Eating (L)": "False",
    "Time of Eating (D)": "False",
    "Food Type": "Nutritious, Gluten-Free",
    "Ratings": "5",
    "Cholesterol": "0",
    "Sodium": "0",
    "Saturated Fat": "0",
    "Sugar": "0",
    "Type": "Griddle-cooked",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Kal Dosa\n\n#### 2. **Description**  \n> Kal D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Kal Dosa is a popular variation of the regular...
#
#         Region Time of Eating (B) Time of Eating (L) Time of Eating (D)  \
# 0  South India               True              False              False
#
#                  Food Type Ratings  ... Protein Cholesterol Sodium  \
# 0  Nutritious, Gluten-Free       5  ...       6           0      0
#
#   Saturated Fat Sugar            Type Food Type (Veg/Non-Veg/Vegan)  \
# 0             0     0  Griddle-cooked                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                         Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Kal Dosa\n\n#### 2. **Description**  \n> Kal D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Kal Dosa is a popular variation of the regular...
#
#         Region Time of Eating (B) Time of Eating (L) Time of Eating (D)  \
# 0  South India               True              False              False
#
#                  Food Type Ratings  ... Protein Cholesterol Sodium  \
# 0  Nutritious, Gluten-Free       5  ...       6           0      0
#
#   Saturated Fat Sugar            Type Food Type (Veg/Non-Veg/Vegan)  \
# 0             0     0  Griddle-cooked                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                         Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Set Dosa
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Set Dosa

#### 2. **Description**  
> Set Dosa is a soft, spongy version of the traditional dosa served in stacks of three. This popular Karnataka breakfast dish is mild, fluffy, and pairs well with vegetable sagu or coconut chutney.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups rice
  - 1/4 cup urad dal
  - 2 tbsp poha (flattened rice)
  - 1/4 tsp fenugreek seeds
  - Salt (to taste)
- **For Cooking:**
  - Oil or ghee (for greasing and drizzling)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 hours (for soaking and fermenting)  
- **Cooking Time:** 20 minutes  
- **Total Time:** ~10 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Soak the rice, urad dal, fenugreek seeds, and poha for 6-8 hours in water.  
2. Grind the soaked ingredients into a smooth batter, adding water as needed. Add salt and mix well.  
3. Allow the batter to ferment for 8-10 hours or overnight until it rises and becomes light and airy.  
4. Heat a non-stick pan or tava on medium heat. Grease lightly with oil or ghee.  
5. Pour a ladleful of batter and spread gently into a small, thick circle. Drizzle oil or ghee around the edges.  
6. Cook until bubbles form and the dosa turns slightly golden. Serve hot.  

---

#### 6. **Tips**  
- Use thick poha for a soft texture.  
- Ensure the batter consistency is neither too thick nor too watery.  

---

#### 7. **Serving Suggestions**  
- Serve with vegetable sagu, coconut chutney, or tomato chutney.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 34 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Not Specified"  # Use default for missing values

# Fill additional columns with default or logical values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Image Not Available",
    "Region": "South India - Karnataka",
    "Time of Eating (B)": True,  # Breakfast
    "Time of Eating (L)": False,  # Not typically lunch
    "Time of Eating (D)": False,  # Not typically dinner
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 30,
    "Saturated Fat": 0.5,
    "Sugar": 0,
    "Type": "Pan-Cooked Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Good for Energy"
})

# Define column order
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Set Dosa\n\n#### 2. **Description**  \n> Set D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Set Dosa is a soft, spongy version of the trad...      Not Specified
#
#                  Photo                   Region  Time of Eating (B)  \
# 0  Image Not Available  South India - Karnataka                True
#
#    Time of Eating (L)  Time of Eating (D)             Food Type  Ratings  ...  \
# 0               False               False  Healthy, Gluten-Free        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar             Type  \
# 0       6           0     30           0.5      0  Pan-Cooked Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Set Dosa\n\n#### 2. **Description**  \n> Set D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Set Dosa is a soft, spongy version of the trad...      Not Specified
#
#                  Photo                   Region  Time of Eating (B)  \
# 0  Image Not Available  South India - Karnataka                True
#
#    Time of Eating (L)  Time of Eating (D)             Food Type  Ratings  ...  \
# 0               False               False  Healthy, Gluten-Free        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar             Type  \
# 0       6           0     30           0.5      0  Pan-Cooked Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Medu Vada

#### 2. **Description**  
> Medu Vada is a traditional South Indian deep-fried snack made from urad dal. Known for its crispy exterior and soft, fluffy interior, it is often served with coconut chutney and sambar.

---

#### 3. **Ingredients**  
- **For Vada Batter:**
  - 1 cup urad dal (black gram, split and skinless)
  - 1 tsp cumin seeds
  - 1 tsp peppercorns (optional)
  - 2 tbsp finely chopped onions
  - 1 tbsp curry leaves (finely chopped)
  - 1 tbsp green chilies (finely chopped)
  - 1/2 tsp asafoetida (hing)
  - Salt (to taste)
  - Water (as required)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 3 hours (for soaking and grinding)  
- **Cooking Time:** 20-25 minutes  
- **Total Time:** ~3 hours 25 minutes  

---

#### 5. **How to Prepare**  
1. Wash and soak urad dal in enough water for 3 hours.  
2. Drain the water and grind the soaked dal into a smooth, thick batter, adding water gradually as needed.  
3. Add cumin seeds, peppercorns, chopped onions, curry leaves, green chilies, asafoetida, and salt to the batter. Mix well.  
4. Heat oil in a deep frying pan or wok on medium heat.  
5. Wet your hands, take a small portion of the batter, shape it into a round patty with a hole in the center (doughnut shape), and gently slide it into the hot oil.  
6. Fry the vadas until golden brown and crispy on all sides. Drain excess oil using paper towels.  
7. Serve hot with coconut chutney and sambar.  

---

#### 6. **Tips**  
- Use a wet hand to shape the batter easily.  
- Ensure the oil is hot but not smoking for perfectly cooked vadas.  

---

#### 7. **Serving Suggestions**  
- Pair Medu Vada with coconut chutney, tomato chutney, or hot sambar.  
- Serve as a snack or as part of a traditional South Indian breakfast.  

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 20 g  
- **Fat:** 10 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # Default value if data is missing

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with values ensuring no nulls
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", "N/A"),
    "Photo": "N/A",
    "Region": "South India",
    "Time of Eating (B)": True,  # Suitable for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Fried, Vegetarian",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": "Moderate",
    "Saturated Fat": "Low",
    "Sugar": 0,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Breakfast",
    "Category (Diabetic/BP)": "Not Suitable",
    "Category (Muscle Gain)": "Protein Rich"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Medu Vada\n\n#### 2. **Description**  \n> Medu...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Medu Vada is a traditional South Indian deep-f...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#            Food Type  Ratings  ... Protein Cholesterol    Sodium  \
# 0  Fried, Vegetarian      4.8  ...       6           0  Moderate
#
#   Saturated Fat  Sugar         Type Food Type (Veg/Non-Veg/Vegan)  \
# 0           Low      0  Fried Snack                           Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast           Not Suitable
#
#   Category (Muscle Gain)
# 0           Protein Rich
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Medu Vada\n\n#### 2. **Description**  \n> Medu...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Medu Vada is a traditional South Indian deep-f...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#            Food Type  Ratings  ... Protein Cholesterol    Sodium  \
# 0  Fried, Vegetarian      4.8  ...       6           0  Moderate
#
#   Saturated Fat  Sugar         Type Food Type (Veg/Non-Veg/Vegan)  \
# 0           Low      0  Fried Snack                           Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Breakfast           Not Suitable
#
#   Category (Muscle Gain)
# 0           Protein Rich
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Masala Vada

#### 2. **Description**  
> Masala Vada is a crispy, deep-fried lentil fritter flavored with spices, popular in South Indian cuisine. It’s a perfect tea-time snack, often served with coconut chutney or green chutney.

---

#### 3. **Ingredients**  
- **For the Vada:**
  - 1 cup chana dal (split Bengal gram)
  - 1 onion (finely chopped)
  - 2-3 green chilies (finely chopped)
  - 1/4 cup fresh coriander leaves (chopped)
  - 5-6 curry leaves (chopped)
  - 1 tsp fennel seeds
  - 1/2 tsp cumin seeds
  - A pinch of asafoetida (optional)
  - Salt (to taste)
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 2 hours (soaking time included)  
- **Cooking Time:** 20-30 minutes  
- **Total Time:** ~2 hours 30 minutes  

---

#### 5. **How to Prepare**  
1. Wash and soak the chana dal in water for 2 hours. Drain well.  
2. Grind the soaked dal coarsely in a blender without adding water. Reserve a few whole lentils for added texture.  
3. Transfer the ground dal to a bowl and mix in the onions, green chilies, coriander leaves, curry leaves, fennel seeds, cumin seeds, asafoetida, and salt.  
4. Heat oil in a deep frying pan over medium heat.  
5. Shape small portions of the mixture into flat, round patties.  
6. Fry the vadas in hot oil until golden brown and crispy. Drain on paper towels.  
7. Serve hot with chutneys or as a standalone snack.

---

#### 6. **Tips**  
- For an extra crunch, leave some dal whole instead of grinding it entirely.  
- If the mixture feels too wet, add a tablespoon of rice flour.  
- Fry on medium heat to ensure even cooking.

---

#### 7. **Serving Suggestions**  
- Serve masala vada with coconut chutney or mint chutney.  
- Enjoy it as an accompaniment to sambar rice or rasam rice.

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal (per serving)  
- **Protein:** 6 g  
- **Carbohydrates:** 20 g  
- **Fat:** 10 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else ""

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "https://example.com/masala-vada.jpg",
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Example for dinner/snack
    "Food Type": "Spicy, Crunchy",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": 5,
    "Saturated Fat": 2,
    "Sugar": 0,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not recommended",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Masala Vada\n\n#### 2. **Description**  \n> Ma...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Masala Vada is a crispy, deep-fried lentil fri...
#
#                                  Photo       Region  Time of Eating (B)  \
# 0  https://example.com/masala-vada.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)       Food Type  Ratings  ...  \
# 0               False                True  Spicy, Crunchy      4.8  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar         Type  \
# 0       6           0      5             2      0  Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Not recommended
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Masala Vada\n\n#### 2. **Description**  \n> Ma...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Masala Vada is a crispy, deep-fried lentil fri...
#
#                                  Photo       Region  Time of Eating (B)  \
# 0  https://example.com/masala-vada.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)       Food Type  Ratings  ...  \
# 0               False                True  Spicy, Crunchy      4.8  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar         Type  \
# 0       6           0      5             2      0  Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Not recommended
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Thattai

#### 2. **Description**  
> Thattai is a traditional South Indian crispy snack made with rice flour and spices. It is a popular festival treat, particularly during Diwali and Krishna Jayanthi.

---

#### 3. **Ingredients**  
- **Dry Ingredients:**
  - 2 cups rice flour
  - 2 tbsp urad dal flour
  - 1 tsp red chili powder
  - 1/2 tsp asafoetida (hing)
  - 1 tsp sesame seeds
  - Salt (to taste)
- **Wet Ingredients:**
  - 1/4 cup butter (softened)
  - Water (as required)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 30 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** 50 minutes  

---

#### 5. **How to Prepare**  
1. Mix rice flour, urad dal flour, red chili powder, asafoetida, sesame seeds, and salt in a mixing bowl.  
2. Add softened butter and mix until the flour is crumbly. Gradually add water and knead into a firm dough.  
3. Divide the dough into small balls and flatten each ball into a thin disc on a greased surface or parchment paper.  
4. Heat oil in a deep frying pan over medium heat. Fry the discs in batches until golden and crisp.  
5. Drain on paper towels and allow them to cool completely. Store in an airtight container.

---

#### 6. **Tips**  
- Ensure the dough is firm but pliable to make shaping easier.  
- Always fry on medium heat to prevent the Thattai from burning.  

---

#### 7. **Serving Suggestions**  
- Serve Thattai with tea or coffee for an evening snack.  
- Pack it as a snack for travel or picnics.

---

#### 8. **Nutritional Information**  
- **Calories:** 120 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 15 g  
- **Fat:** 5 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""

# Fill additional columns with default or logical values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "default_image.jpg",  # Placeholder for image
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,
    "Food Type": "Crunchy Snack",
    "Ratings": 4.5,  # Example rating
    "Cholesterol": 0,  # Assume no cholesterol in a vegetarian snack
    "Sodium": 50,  # Sample sodium content
    "Saturated Fat": 1,  # Approximate value
    "Sugar": 0,  # Not a sweet dish
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Occasional Treat",  # Suitable for occasional consumption
    "Category (Muscle Gain)": "Not Recommended"  # Not a muscle gain food
})

# Define the DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Thattai\n\n#### 2. **Description**  \n> Thatta...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Thattai is a traditional South Indian crispy s...
#
#                Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  default_image.jpg  South India               False               False
#
#    Time of Eating (D)      Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0                True  Crunchy Snack      4.5  ...       2           0     50
#
#   Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             1      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack       Occasional Treat
#
#   Category (Muscle Gain)
# 0        Not Recommended
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Thattai\n\n#### 2. **Description**  \n> Thatta...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Thattai is a traditional South Indian crispy s...
#
#                Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  default_image.jpg  South India               False               False
#
#    Time of Eating (D)      Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0                True  Crunchy Snack      4.5  ...       2           0     50
#
#   Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             1      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack       Occasional Treat
#
#   Category (Muscle Gain)
# 0        Not Recommended
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Banana Chips
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Banana Chips

#### 2. **Description**  
> Banana Chips are thinly sliced, crispy snacks made from raw bananas. Popular in South India, these chips are deep-fried to golden perfection and are a staple during festive seasons.

---

#### 3. **Ingredients**  
- **For Chips:**
  - 3 raw bananas
  - 1/2 tsp turmeric powder
  - Salt (to taste)
  - Water (as needed)
- **For Frying:**
  - Coconut oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 15 minutes  
- **Total Time:** 25 minutes  

---

#### 5. **How to Prepare**  
1. Peel the raw bananas and slice them thinly using a mandoline or a sharp knife.  
2. Mix water with turmeric powder and salt in a bowl. Soak the banana slices in this mixture for 5 minutes.  
3. Heat coconut oil in a deep frying pan over medium heat.  
4. Pat the banana slices dry and fry them in batches. Ensure they don’t overlap. Fry until they turn crispy and golden brown.  
5. Remove the chips and place them on a paper towel to remove excess oil.  

---

#### 6. **Tips**  
- Use raw bananas for the best texture and flavor.  
- Ensure the oil temperature is consistent to avoid soggy chips.  

---

#### 7. **Serving Suggestions**  
- Enjoy as a snack with tea or coffee.  
- Store in an airtight container to retain crispiness.

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 20 g  
- **Fat:** 14 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Not available"  # Default value for missing data

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "banana_chips.jpg",  # Sample value for photo
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Snack",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": 200,  # Example sodium value
    "Saturated Fat": 12,
    "Sugar": 2,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Vegan",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "Not Muscle Gain"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Banana Chips\n\n#### 2. **Description**  \n> B...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Banana Chips are thinly sliced, crispy snacks ...      Not available
#
#               Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  banana_chips.jpg  South India               False               False
#
#    Time of Eating (D) Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0               False     Snack      4.5  ...       2           0    200
#
#   Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0            12      2  Fried Snack                          Vegan
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Not Muscle Gain
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Banana Chips\n\n#### 2. **Description**  \n> B...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Banana Chips are thinly sliced, crispy snacks ...      Not available
#
#               Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  banana_chips.jpg  South India               False               False
#
#    Time of Eating (D) Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0               False     Snack      4.5  ...       2           0    200
#
#   Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0            12      2  Fried Snack                          Vegan
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Not Muscle Gain
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Murukku

#### 2. **Description**  
> Murukku is a traditional South Indian savory snack made with rice flour and lentil flour, shaped into spirals, and deep-fried until golden and crispy. Perfect for festive occasions and tea-time snacks.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 2 cups rice flour
  - 1/2 cup urad dal flour
  - 1 tsp cumin seeds
  - 1/4 tsp asafoetida
  - 2 tbsp butter
  - Salt (to taste)
  - Water (as required)
- **For Frying:**
  - Oil (for deep-frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 30 minutes  
- **Total Time:** 50 minutes  

---

#### 5. **How to Prepare**  
1. Mix Ingredients: In a large bowl, combine rice flour, urad dal flour, cumin seeds, asafoetida, and salt. Mix well.  
2. Add Butter: Add melted butter to the flour mixture and knead into a smooth dough using water.  
3. Shape Murukku: Place the dough in a murukku press with the desired nozzle and pipe the dough into spirals on a butter paper or plate.  
4. Fry Murukku: Heat oil in a deep pan and fry the spirals on medium heat until golden and crispy. Remove and drain excess oil on a paper towel.  
5. Serve: Allow to cool and store in an airtight container. Serve as a snack with tea or coffee.

---

#### 6. **Tips**  
- Ensure the dough is soft but not sticky for easy pressing.  
- Use medium heat while frying to cook evenly and prevent burning.  

---

#### 7. **Serving Suggestions**  
- Pair murukku with coffee or tea.  
- Serve as part of a festive snack platter.

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 25 g  
- **Fat:** 9 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not Available"

# Fill additional columns with default values or specific information
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Placeholder URL for Murukku Photo",  # Replace with actual photo URL or path if available
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Savory Snack",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": "Minimal",
    "Saturated Fat": 2,
    "Sugar": 0,
    "Type": "Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Recommended",
    "Category (Muscle Gain)": "Not Specific"
})

# Define column order
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert to DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Murukku\n\n#### 2. **Description**  \n> Murukk...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Murukku is a traditional South Indian savory s...      Not Available
#
#                                Photo       Region  Time of Eating (B)  \
# 0  Placeholder URL for Murukku Photo  South India               False
#
#    Time of Eating (L)  Time of Eating (D)     Food Type  Ratings  ... Protein  \
# 0               False               False  Savory Snack      4.5  ...       4
#
#   Cholesterol   Sodium Saturated Fat  Sugar   Type  \
# 0           0  Minimal             2      0  Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Not Recommended
#
#   Category (Muscle Gain)
# 0           Not Specific
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Murukku\n\n#### 2. **Description**  \n> Murukk...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Murukku is a traditional South Indian savory s...      Not Available
#
#                                Photo       Region  Time of Eating (B)  \
# 0  Placeholder URL for Murukku Photo  South India               False
#
#    Time of Eating (L)  Time of Eating (D)     Food Type  Ratings  ... Protein  \
# 0               False               False  Savory Snack      4.5  ...       4
#
#   Cholesterol   Sodium Saturated Fat  Sugar   Type  \
# 0           0  Minimal             2      0  Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Not Recommended
#
#   Category (Muscle Gain)
# 0           Not Specific
#
# ...

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Potato Bonda
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Bonda (Potato Bonda)

#### 2. **Description**  
> Potato Bonda is a crispy, deep-fried snack from South India, stuffed with spicy mashed potatoes and coated in a chickpea flour batter. It is a popular tea-time snack often enjoyed with chutneys.

---

#### 3. **Ingredients**  
- **For Potato Filling:**
  - 3 medium-sized potatoes (boiled and mashed)
  - 1 green chili (finely chopped)
  - 1/2 tsp mustard seeds
  - 1/2 tsp turmeric powder
  - A few curry leaves
  - 1 tbsp oil
  - Salt (to taste)
- **For Batter:**
  - 1 cup chickpea flour (besan)
  - 1/4 tsp turmeric powder
  - 1/4 tsp chili powder
  - A pinch of asafoetida (hing)
  - Water (as required)
  - Salt (to taste)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 30 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** 50 minutes  

---

#### 5. **How to Prepare**  
1. **Prepare the Potato Filling:** Heat oil in a pan, add mustard seeds, curry leaves, and green chilies. Add mashed potatoes, turmeric powder, and salt. Mix well and cook for 2-3 minutes. Allow the filling to cool and shape it into small balls.  
2. **Prepare the Batter:** In a mixing bowl, combine chickpea flour, turmeric powder, chili powder, asafoetida, and salt. Add water gradually to form a thick, smooth batter.  
3. **Fry the Bondas:** Heat oil in a deep frying pan. Dip each potato ball into the batter, ensuring it is coated evenly, and fry until golden brown.  
4. **Serve:** Drain on paper towels and serve hot with chutney or ketchup.  

---

#### 6. **Tips**  
- Add ginger-garlic paste to the potato mixture for extra flavor.  
- Ensure the batter is thick to prevent it from sliding off the filling while frying.  

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney, tamarind chutney, or mint chutney.  
- Pair with a cup of masala tea for the perfect snack combo.  

---

#### 8. **Nutritional Information**  
- **Calories:** 190 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 20 g  
- **Fat:** 10 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not specified"  # Use default value instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Placeholder image URL",  # Default placeholder for no photo
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": True,  # Popular for lunch as a snack
    "Time of Eating (D)": False,
    "Food Type": "Crispy, Fried Snack",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": 50,
    "Saturated Fat": 2,
    "Sugar": 1,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not recommended",
    "Category (Muscle Gain)": "Not specified"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Bonda (Potato Bonda)\n\n#### 2. **Description*...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Potato Bonda is a crispy, deep-fried snack fro...      Not specified
#
#                    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Placeholder image URL  South India                True                True
#
#    Time of Eating (D)            Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Crispy, Fried Snack      4.8  ...       4           0
#
#   Sodium Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0     50             2      1  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Not recommended
#
#   Category (Muscle Gain)
# 0          Not specified
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Bonda (Potato Bonda)\n\n#### 2. **Description*...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Potato Bonda is a crispy, deep-fried snack fro...      Not specified
#
#                    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Placeholder image URL  South India                True                True
#
#    Time of Eating (D)            Food Type  Ratings  ... Protein Cholesterol  \
# 0               False  Crispy, Fried Snack      4.8  ...       4           0
#
#   Sodium Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0     50             2      1  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Not recommended
#
#   Category (Muscle Gain)
# 0          Not specified
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Sundal (Chickpea Sundal)

#### 2. **Description**  
> Sundal is a flavorful South Indian dish made with cooked chickpeas, seasoned with coconut and spices. It is commonly prepared during festivals or as a quick, healthy snack.

---

#### 3. **Ingredients**  
- **For Cooking Chickpeas:**
  - 1 cup chickpeas (soaked overnight)
  - Water (for boiling)
  - Salt (to taste)
- **For Tempering:**
  - 1 tbsp oil
  - 1/2 tsp mustard seeds
  - 1-2 dried red chilies
  - A pinch of asafoetida (hing)
  - 6-8 curry leaves
- **For Garnish:**
  - 1/4 cup freshly grated coconut
  - Fresh coriander leaves (chopped)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 8 hours (for soaking chickpeas)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Soak the chickpeas overnight in enough water. Drain the water and rinse thoroughly.  
2. Cook the chickpeas with fresh water and salt in a pressure cooker until soft (3-4 whistles). Drain excess water.  
3. Heat oil in a pan and add mustard seeds. Once they splutter, add red chilies, curry leaves, and asafoetida. Sauté for a few seconds.  
4. Add the cooked chickpeas to the pan and mix well with the tempering. Adjust salt if needed.  
5. Garnish with grated coconut and fresh coriander leaves. Mix well and serve warm.  

---

#### 6. **Tips**  
- You can use canned chickpeas for convenience. Rinse and drain them before using.  
- Add a squeeze of lemon juice for a tangy twist.  

---

#### 7. **Serving Suggestions**  
- Serve Sundal as a healthy snack or side dish.  
- It pairs well with South Indian meals or as part of festive offerings.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 8 g  
- **Carbohydrates:** 28 g  
- **Fat:** 4 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # Fill with placeholder value instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or fallback placeholders
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", "N/A"),
    "Photo": "Available Soon",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,
    "Food Type": "Healthy, High Protein, Vegan",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": 5,
    "Saturated Fat": 0.1,
    "Sugar": 1.5,
    "Type": "Dry Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Vegan",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Suitable for Diabetics",
    "Category (Muscle Gain)": "High Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Sundal (Chickpea Sundal)\n\n#### 2. **Descript...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Sundal is a flavorful South Indian dish made w...                N/A
#
#             Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available Soon  South India                True               False
#
#    Time of Eating (D)                     Food Type  Ratings  ... Protein  \
# 0                True  Healthy, High Protein, Vegan      4.5  ...       8
#
#   Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0           0      5           0.1    1.5  Dry Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                          Vegan
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  Category (Diabetic/BP)  \
# 0                                              Snack  Suitable for Diabetics
#
#   Category (Muscle Gain)
# 0           High Protein
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Sundal (Chickpea Sundal)\n\n#### 2. **Descript...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Sundal is a flavorful South Indian dish made w...                N/A
#
#             Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available Soon  South India                True               False
#
#    Time of Eating (D)                     Food Type  Ratings  ... Protein  \
# 0                True  Healthy, High Protein, Vegan      4.5  ...       8
#
#   Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0           0      5           0.1    1.5  Dry Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                          Vegan
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  Category (Diabetic/BP)  \
# 0                                              Snack  Suitable for Diabetics
#
#   Category (Muscle Gain)
# 0           High Protein
#
# ...

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Masala Bajji (Chili Bajji)

#### 2. **Description**  
> Masala Bajji, also known as Chili Bajji, is a popular Indian snack. These deep-fried chili fritters are spicy and crispy, making them a perfect tea-time treat or street food delight.

---

#### 3. **Ingredients**  
- **For Bajji Batter:**
  - 1 cup gram flour (besan)
  - 2 tbsp rice flour
  - 1/4 tsp turmeric powder
  - 1/2 tsp red chili powder
  - 1/2 tsp carom seeds (ajwain)
  - Water (as required)
  - Salt (to taste)
- **For Stuffing:**
  - 6 large green chilies
  - 1/4 tsp roasted cumin powder
  - 1/4 tsp chaat masala
  - 1/2 cup boiled and mashed potatoes
- **For Frying:**
  - Oil (as required)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 15 minutes  
- **Total Time:** 35 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Stuffing: Mix mashed potatoes, roasted cumin powder, chaat masala, and salt. Slit green chilies lengthwise and remove seeds, then stuff them with the prepared mixture.  
2. Make Batter: In a bowl, combine gram flour, rice flour, turmeric, red chili powder, carom seeds, salt, and water to form a thick batter.  
3. Coat and Fry: Heat oil in a pan. Dip stuffed chilies into the batter, ensuring an even coating, and fry until golden brown and crispy.  
4. Serve: Remove from oil, drain on a paper towel, and serve hot.

---

#### 6. **Tips**  
- Serve with coconut or tamarind chutney for an authentic flavor.  
- Adjust the spice level by choosing milder or spicier green chilies.  

---

#### 7. **Serving Suggestions**  
- Serve with a side of tangy tamarind chutney or mint coriander chutney.  
- Pair with a cup of hot masala tea for a delightful snack.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 20 g  
- **Fat:** 9 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not Available"

# Fill additional columns to ensure no null values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Placeholder for Photo URL",
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Snack during evening hours
    "Food Type": "Spicy, Crispy Snack",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": 200,
    "Saturated Fat": 1,
    "Sugar": 1,
    "Type": "Deep-Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Recommended for Diabetics",
    "Category (Muscle Gain)": "Energy Boost Snack"
})

# Define DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Create the DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Masala Bajji (Chili Bajji)\n\n#### 2. **Descri...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Masala Bajji, also known as Chili Bajji, is a ...      Not Available
#
#                        Photo       Region  Time of Eating (B)  \
# 0  Placeholder for Photo URL  South India               False
#
#    Time of Eating (L)  Time of Eating (D)            Food Type  Ratings  ...  \
# 0               False                True  Spicy, Crispy Snack      4.5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar              Type  \
# 0       4           0    200             1      1  Deep-Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  \
# 0                                              Snack
#
#           Category (Diabetic/BP) Category (Muscle Gain)
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Masala Bajji (Chili Bajji)\n\n#### 2. **Descri...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Masala Bajji, also known as Chili Bajji, is a ...      Not Available
#
#                        Photo       Region  Time of Eating (B)  \
# 0  Placeholder for Photo URL  South India               False
#
#    Time of Eating (L)  Time of Eating (D)            Food Type  Ratings  ...  \
# 0               False                True  Spicy, Crispy Snack      4.5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar              Type  \
# 0       4           0    200             1      1  Deep-Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  \
# 0                                              Snack
#
#           Category (Diabetic/BP) Category (Muscle Gain)
# ...

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Onion Pakoda

#### 2. **Description**  
> Onion Pakoda is a crispy, deep-fried Indian snack made from sliced onions and chickpea flour. It is a popular evening snack, often served with tea during the monsoon season.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 2 cups chickpea flour (besan)
  - 2 medium-sized onions, thinly sliced
  - 1/2 cup rice flour
  - 1 tsp red chili powder
  - 1/2 tsp turmeric powder
  - 1 tsp carom seeds (ajwain)
  - 2 green chilies, finely chopped
  - 2 tbsp coriander leaves, finely chopped
  - Salt to taste
  - Water (as required)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** ~35 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Ingredients: Thinly slice the onions and keep them aside.  
2. Make the Batter: In a large bowl, combine chickpea flour, rice flour, red chili powder, turmeric, carom seeds, and salt. Add water gradually to form a thick, slightly lumpy batter. Add sliced onions, green chilies, and coriander leaves to the batter and mix well.  
3. Heat Oil: Heat oil in a deep frying pan over medium flame.  
4. Fry Pakodas: Drop small portions of the batter into the hot oil using your fingers or a spoon. Fry until golden brown and crisp. Remove with a slotted spoon and drain on paper towels.  
5. Serve: Serve hot with mint chutney, tamarind chutney, or tomato ketchup.  

---

#### 6. **Tips**  
- Add a pinch of baking soda to the batter for extra fluffiness.  
- Use cold water in the batter to make the pakodas crispier.  

---

#### 7. **Serving Suggestions**  
- Best enjoyed with a hot cup of masala tea or coffee.  
- Add finely chopped spinach or methi leaves to the batter for variation.  

---

#### 8. **Nutritional Information**  
- **Calories:** 220 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 30 g  
- **Fat:** 10 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()

# Define the additional columns
additional_data = {
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "Image of Onion Pakoda",
    "Region": "South India",
    "Time of Eating (B)": False,  # Not usually eaten for breakfast
    "Time of Eating (L)": False,  # Not usually eaten for lunch
    "Time of Eating (D)": True,  # Common as a snack/dinner side
    "Food Type": "Snack, Gluten-Free",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": 350,
    "Saturated Fat": 1.5,
    "Sugar": 2,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Moderate Sodium",
    "Category (Muscle Gain)": "Rich in Protein"
}

# Combine extracted data and additional data
extracted_data.update(additional_data)

# Convert the data into a DataFrame
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Onion Pakoda\n\n#### 2. **Description**  \n> O...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Onion Pakoda is a crispy, deep-fried Indian sn...
#
#                    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Image of Onion Pakoda  South India               False               False
#
#    Time of Eating (D)           Food Type  Ratings  ...  Protein Cholesterol  \
# 0                True  Snack, Gluten-Free      4.8  ...        6           0
#
#   Sodium Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    350           1.5      2  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Moderate Sodium
#
#   Category (Muscle Gain)
# 0        Rich in Protein
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Onion Pakoda\n\n#### 2. **Description**  \n> O...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Onion Pakoda is a crispy, deep-fried Indian sn...
#
#                    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Image of Onion Pakoda  South India               False               False
#
#    Time of Eating (D)           Food Type  Ratings  ...  Protein Cholesterol  \
# 0                True  Snack, Gluten-Free      4.8  ...        6           0
#
#   Sodium Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    350           1.5      2  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack        Moderate Sodium
#
#   Category (Muscle Gain)
# 0        Rich in Protein
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Ribbon Pakoda
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Ribbon Pakoda

#### 2. **Description**  
> Ribbon Pakoda is a crunchy, savory snack from South India made using rice flour, chickpea flour, and spices. It’s typically served during festivals or as a light snack, offering a combination of crispy texture and spicy flavor.

---

#### 3. **Ingredients**  
- **For Dough:**
  - 1 cup rice flour
  - 1/4 cup chickpea flour (besan)
  - 1/2 tsp cumin seeds
  - 1/4 tsp asafoetida (hing)
  - 1/2 tsp red chili powder
  - 1/2 tsp black pepper powder
  - Salt to taste
  - 1 tbsp hot melted ghee or butter
  - Water (as needed)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes (for making the dough)  
- **Cooking Time:** 15-20 minutes (for frying)  
- **Total Time:** ~40 minutes  

---

#### 5. **How to Prepare**  
1. Prepare the Dough: In a large mixing bowl, combine rice flour, chickpea flour, cumin seeds, asafoetida, chili powder, black pepper, and salt. Add melted ghee or butter, then mix the dry ingredients well.
2. Add water little by little to form a smooth, non-sticky dough. It should have a consistency similar to soft chapati dough.
3. Heat oil in a deep pan or kadai over medium heat for frying.
4. Shape the Pakodas: Fill a ribbon pakoda maker with the prepared dough. Once the oil is hot enough (test by dropping a small piece of dough into the oil – it should rise immediately), press the dough into the oil in a ribbon-like pattern.
5. Fry the Pakodas: Fry the dough ribbons until they turn golden brown and crispy. Drain the excess oil on paper towels.
6. Serve: Allow to cool slightly and serve with tea or as an appetizer.

---

#### 6. **Tips**  
- Be sure to adjust the amount of water to get the right dough consistency for shaping.  
- You can add a pinch of turmeric to enhance the color and flavor.  

---

#### 7. **Serving Suggestions**  
- Serve as a tea-time snack with a cup of coffee or masala chai.  
- Can be paired with a variety of chutneys like coconut chutney or tamarind chutney.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 18 g  
- **Fat:** 10 g
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or appropriate data
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Ribbon_Pakoda_Image.jpg",  # You can specify a path for an image
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Crunchy, Savory Snack",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 1,  # Approximate value based on ingredients
    "Sugar": 0,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",  # Since fried and has carbs
    "Category (Muscle Gain)": "Not Muscle Gain Friendly"  # Not suitable for muscle gain diets
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Ribbon Pakoda\n\n#### 2. **Description**  \n> ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Ribbon Pakoda is a crunchy, savory snack from ...               None
#
#                      Photo       Region  Time of Eating (B)  \
# 0  Ribbon_Pakoda_Image.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)              Food Type  Ratings  \
# 0               False               False  Crunchy, Savory Snack        5
#
#    ...  Protein Cholesterol Sodium Saturated Fat  Sugar         Type  \
# 0  ...        4           0      0             1      0  Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack  Not Diabetic Friendly
#
#      Category (Muscle Gain)
# 0  Not Muscle Gain Friendly
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Ribbon Pakoda\n\n#### 2. **Description**  \n> ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Ribbon Pakoda is a crunchy, savory snack from ...               None
#
#                      Photo       Region  Time of Eating (B)  \
# 0  Ribbon_Pakoda_Image.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)              Food Type  Ratings  \
# 0               False               False  Crunchy, Savory Snack        5
#
#    ...  Protein Cholesterol Sodium Saturated Fat  Sugar         Type  \
# 0  ...        4           0      0             1      0  Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack  Not Diabetic Friendly
#
#      Category (Muscle Gain)
# 0  Not Muscle Gain Friendly
#
# ...

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Omapodi
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Omapodi

#### 2. **Description**  
> Omapodi is a crispy, crunchy snack made from gram flour and flavored with carom seeds (ajwain). It is a popular savory treat in South India, commonly enjoyed during festivals or as an accompaniment with tea.

---

#### 3. **Ingredients**  
- **For Dough:**
  - 1 cup gram flour (besan)
  - 1 tbsp rice flour
  - 1 tsp carom seeds (ajwain)
  - 1/2 tsp cumin seeds
  - Salt (to taste)
  - Water (as needed)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10-15 minutes  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~30 minutes

---

#### 5. **How to Prepare**  
1. In a bowl, mix the gram flour, rice flour, carom seeds, cumin seeds, and salt.
2. Gradually add water and knead into a smooth and firm dough.
3. Heat oil in a deep frying pan. Fit an omapodi maker with small holes.
4. Press the dough through the omapodi maker into the hot oil.
5. Fry until the omapodi turns golden and crisp. Remove from the oil and drain excess oil on paper towels.
6. Let it cool, and serve as a crunchy snack or appetizer.

---

#### 6. **Tips**  
- Make sure the dough is firm, not too soft, for the right texture.
- Store in an airtight container for up to a week for freshness.

---

#### 7. **Serving Suggestions**  
- Serve with tea or coffee as a snack.
- Pair with a tangy tamarind chutney or a mint-coriander dip.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 25 g  
- **Fat:** 8 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Assign an empty string instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": False,  # Not for breakfast in this case
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Typically a snack item
    "Food Type": "Crispy, Savory",
    "Ratings": 4,  # Example rating
    "Cholesterol": 0,
    "Sodium": 200,  # Assuming some sodium content from frying
    "Saturated Fat": 0.5,
    "Sugar": 0,  # Very low sugar
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Diabetic Friendly",  # Though deep-fried, it's considered friendly in moderation
    "Category (Muscle Gain)": "High Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Omapodi\n\n#### 2. **Description**  \n> Omapod...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Omapodi is a crispy, crunchy snack made from g...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False               False                True
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Crispy, Savory        4  ...       5           0    200           0.5
#
#    Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High Protein
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Omapodi\n\n#### 2. **Description**  \n> Omapod...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Omapodi is a crispy, crunchy snack made from g...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False               False                True
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Crispy, Savory        4  ...       5           0    200           0.5
#
#    Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High Protein
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Maddur Vada
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Maddur Vada

#### 2. **Description**  
> Maddur Vada is a popular South Indian savory snack made from rice flour and all-purpose flour mixed with spices and deep-fried until golden brown. It is crunchy on the outside and soft on the inside, typically served with chutneys or sambar.

---

#### 3. **Ingredients**  
- **For Vada:**
  - 1 cup rice flour
  - 1/4 cup all-purpose flour
  - 1/4 cup semolina (optional)
  - 1 medium onion, finely chopped
  - 1-2 green chilies, finely chopped
  - 1/2 tsp cumin seeds
  - 1/2 tsp mustard seeds
  - 1/4 tsp turmeric powder
  - A few curry leaves, chopped
  - 1 tbsp ginger, grated
  - Salt (to taste)
  - Water (as required for mixing)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~40 minutes  

---

#### 5. **How to Prepare**  
1. In a mixing bowl, combine rice flour, all-purpose flour, and semolina.  
2. Add the chopped onions, green chilies, cumin seeds, mustard seeds, turmeric powder, curry leaves, and ginger to the flour mixture.  
3. Add salt and slowly add water to form a thick dough. Mix well and knead the dough until smooth.  
4. Heat oil in a pan for deep frying.  
5. Pinch small portions of the dough and shape them into round or oval vadas, pressing gently in the center.  
6. Deep fry the vadas in hot oil until golden brown and crisp on both sides.  
7. Remove from oil and place them on a paper towel to absorb excess oil.  

---

#### 6. **Tips**  
- For extra crunch, you can add crushed poha (flattened rice) to the dough.  
- You can also make these vadas in different shapes, depending on your preference.

---

#### 7. **Serving Suggestions**  
- Serve Maddur Vada with coconut chutney, sambar, or a tangy tamarind chutney.  
- Best served hot with a cup of chai.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 28 g  
- **Fat:** 6 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # If no match, assign an empty string instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Snack, Crunchy",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Maddur Vada\n\n#### 2. **Description**  \n> Ma...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Maddur Vada is a popular South Indian savory s...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Snack, Crunchy        5  ...       4           0      0             0
#
#    Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Maddur Vada\n\n#### 2. **Description**  \n> Ma...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Maddur Vada is a popular South Indian savory s...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Snack, Crunchy        5  ...       4           0      0             0
#
#    Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Keerai Vada (Spinach Fritters)

#### 2. **Description**  
> Keerai Vada, or Spinach Fritters, is a delicious deep-fried snack from South India. Made with a blend of lentils, fresh spinach, and spices, these crispy fritters are perfect for any occasion. 

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup chana dal (split chickpeas)
  - 1/2 cup toor dal (pigeon peas)
  - 2 cups fresh spinach, chopped
  - 1 medium onion, finely chopped
  - 2 green chilies, chopped
  - 1 tbsp ginger, grated
  - 1 tsp cumin seeds
  - 1/4 tsp hing (asafoetida)
  - Salt (to taste)
  - Water (as needed)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 4-5 hours (for soaking dal)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~5 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Soak the chana dal and toor dal separately in water for 3-4 hours.
2. Drain the dal and grind it coarsely with a little water. Do not make it a smooth paste; it should be slightly grainy.
3. Add the chopped spinach, onions, green chilies, ginger, cumin seeds, hing, and salt to the dal mixture. Mix well.
4. Heat oil in a deep frying pan over medium heat. 
5. Wet your hands and shape the dal mixture into small balls or patties, and flatten them slightly.
6. Carefully drop the vadas into the hot oil and fry them until golden brown and crispy.
7. Remove from oil and drain excess oil on paper towels.
8. Serve hot with coconut chutney or sambar.

---

#### 6. **Tips**  
- Ensure the oil is hot enough before frying to avoid soggy vadas.  
- You can add a handful of rice flour to make the vadas extra crispy.  

---

#### 7. **Serving Suggestions**  
- Serve with coconut chutney, sambar, or tomato chutney.  
- Garnish with fresh coriander leaves for added flavor.

---

#### 8. **Nutritional Information**  
- **Calories:** 190 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 25 g  
- **Fat:** 8 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # If no match, assign empty string

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or fixed strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "keerai_vada_photo.jpg",  # Example placeholder for photo
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Keerai Vada is typically a snack or dinner item
    "Food Type": "Gluten-Free, Vegetarian",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": np.nan  # No specific mention for muscle gain
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Keerai Vada (Spinach Fritters)\n\n#### 2. **De...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Keerai Vada, or Spinach Fritters, is a delicio...
#
#                    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  keerai_vada_photo.jpg  South India               False               False
#
#    Time of Eating (D)                Food Type  Ratings  ... Protein  \
# 0                True  Gluten-Free, Vegetarian        5  ...       6
#
#   Cholesterol Sodium Saturated Fat  Sugar         Type  \
# 0           0      0             0      0  Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Keerai Vada (Spinach Fritters)\n\n#### 2. **De...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Keerai Vada, or Spinach Fritters, is a delicio...
#
#                    Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  keerai_vada_photo.jpg  South India               False               False
#
#    Time of Eating (D)                Food Type  Ratings  ... Protein  \
# 0                True  Gluten-Free, Vegetarian        5  ...       6
#
#   Cholesterol Sodium Saturated Fat  Sugar         Type  \
# 0           0      0             0      0  Fried Snack
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Rava Kesari (Sweet Snack)

#### 2. **Description**  
> Rava Kesari, also known as Sheera or Suji Halwa, is a delicious South Indian sweet dish made with semolina, sugar, ghee, and flavored with cardamom and saffron. It is a popular snack or dessert served during festivals and celebrations.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 1 cup rava (semolina)
  - 1/2 cup sugar
  - 1/4 cup ghee
  - 2 cups water
  - 1/4 cup milk
  - 1/4 tsp cardamom powder
  - A pinch of saffron threads (optional)
- **For Garnish:**
  - Cashews and raisins (fried in ghee)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 5-10 minutes  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~25 minutes  

---

#### 5. **How to Prepare**  
1. Heat a pan and roast the rava in 1 tablespoon of ghee until it turns slightly golden brown.
2. In a separate pan, bring water and milk to a boil. Add saffron threads (if using) to the boiling liquid.
3. Slowly add the boiling liquid to the roasted rava, stirring continuously to avoid lumps.
4. Add sugar to the mixture and stir until it dissolves completely. Cook the mixture until it thickens and the ghee starts to separate.
5. Add the remaining ghee and cardamom powder, stirring well to incorporate.
6. Garnish with fried cashews and raisins, and serve hot.

---

#### 6. **Tips**  
- Use full-fat milk for a richer flavor and texture.  
- If you prefer a less sweet version, reduce the sugar as per your taste.

---

#### 7. **Serving Suggestions**  
- Serve hot or warm as a snack or dessert.  
- It pairs perfectly with coffee or tea.

---

#### 8. **Nutritional Information**  
- **Calories:** 250 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 35 g  
- **Fat:** 12 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # No null values, using empty strings for missing data

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Sweet, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": extracted_data.get("Calories", ""),
    "Type": "Sweet Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Can Be Made Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Rava Kesari (Sweet Snack)\n\n#### 2. **Descrip...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Rava Kesari, also known as Sheera or Suji Halw...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#             Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Sweet, Gluten-Free        5  ...       4           0      0             0
#
#    Sugar        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    250  Sweet Dish                            Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages)  \
# 0                                             Snack
#
#           Category (Diabetic/BP) Category (Muscle Gain)
# 0  Can Be Made Diabetic Friendly
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Rava Kesari (Sweet Snack)\n\n#### 2. **Descrip...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Rava Kesari, also known as Sheera or Suji Halw...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#             Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Sweet, Gluten-Free        5  ...       4           0      0             0
#
#    Sugar        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    250  Sweet Dish                            Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages)  \
# 0                                             Snack
#
#           Category (Diabetic/BP) Category (Muscle Gain)
# 0  Can Be Made Diabetic Friendly
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Thenguzhal
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Thenguzhal

#### 2. **Description**  
> Thenguzhal is a traditional South Indian snack made from rice flour and spices. Known for its crisp texture and flavor, it’s often enjoyed with tea or as a side dish with meals.

---

#### 3. **Ingredients**  
- **For Dough:**
  - 2 cups rice flour
  - 1/2 tsp cumin seeds
  - 1/2 tsp black sesame seeds
  - 1 tsp red chili powder
  - Salt to taste
  - Water (as required)
  - 1 tbsp ghee
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 30 minutes  
- **Cooking Time:** 10-12 minutes  
- **Total Time:** ~40 minutes  

---

#### 5. **How to Prepare**  
1. In a large bowl, mix rice flour, cumin seeds, black sesame seeds, red chili powder, and salt.  
2. Gradually add water and knead into a smooth dough. Add ghee while kneading to make it soft.  
3. Heat oil in a deep frying pan over medium heat.  
4. Once the dough is ready, take a portion and roll it into small logs. Use a thenguzhal press (or a piping bag with a star nozzle) to shape the dough into coils or sticks directly into the hot oil.  
5. Fry in batches until golden brown and crisp. Drain excess oil on paper towels.  
6. Let the thenguzhals cool to room temperature and serve.

---

#### 6. **Tips**  
- Ensure the oil is hot enough before frying to prevent thenguzhals from absorbing too much oil.  
- You can adjust the level of chili powder based on your heat preference.

---

#### 7. **Serving Suggestions**  
- Serve thenguzhal as a snack with tea or coffee.  
- Pair it with chutneys like coconut chutney or tamarind chutney for extra flavor.

---

#### 8. **Nutritional Information**  
- **Calories:** 200 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 32 g  
- **Fat:** 8 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Assign an empty string instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",  # No image URL provided
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Crispy, Savory",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Fried Snack",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Suitable",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Thenguzhal\n\n#### 2. **Description**  \n> The...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Thenguzhal is a traditional South Indian snack...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Crispy, Savory        5  ...       4           0      0             0
#
#    Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack           Not Suitable
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Thenguzhal\n\n#### 2. **Description**  \n> The...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Thenguzhal is a traditional South Indian snack...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#         Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Crispy, Savory        5  ...       4           0      0             0
#
#    Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Fried Snack                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack           Not Suitable
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Mysore Bonda

#### 2. **Description**  
> Mysore Bonda is a popular South Indian snack made from urad dal and rice flour, deep-fried to a golden crisp. It is traditionally served with coconut chutney or sambar and is often enjoyed as a tea-time snack.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup urad dal
  - 2 tbsp rice flour
  - 1 small onion, finely chopped
  - 2 green chilies, finely chopped
  - 1/2 tsp cumin seeds
  - A pinch of asafoetida
  - 1 sprig curry leaves, chopped
  - Salt to taste
  - Water (as required)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 6-8 hours (for soaking the urad dal)  
- **Cooking Time:** 15-20 minutes  
- **Total Time:** ~8 hours 20 minutes  

---

#### 5. **How to Prepare**  
1. Soak the urad dal in water for 6-8 hours. Drain the water.  
2. Grind the soaked urad dal into a smooth batter, adding water as needed to get a thick consistency.  
3. Add chopped onions, green chilies, cumin seeds, asafoetida, curry leaves, and salt. Mix well.  
4. Heat oil in a pan for deep frying.  
5. Wet your hands and take small portions of the batter, shaping them into round balls.  
6. Gently slide the batter balls into the hot oil. Fry until golden brown and crispy.  
7. Drain on paper towels and serve hot.

---

#### 6. **Tips**  
- You can adjust the spiciness by adding more or less green chilies.  
- If the batter is too thick, add a little water to bring it to the right consistency.

---

#### 7. **Serving Suggestions**  
- Serve Mysore Bonda hot with coconut chutney or sambar.  
- You can also serve it with a spicy tomato chutney for an added kick.

---

#### 8. **Nutritional Information**  
- **Calories:** 170 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 24 g  
- **Fat:** 6 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Replace NaN with empty string to avoid null values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",
    "Region": "South India",
    "Time of Eating (B)": True,  # Example for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 0,
    "Sugar": 0,
    "Type": "Deep Fried",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": ""
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Mysore Bonda\n\n#### 2. **Description**  \n> M...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Mysore Bonda is a popular South Indian snack m...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Healthy, Gluten-Free        5  ...       6           0      0
#
#   Saturated Fat  Sugar        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             0      0  Deep Fried                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Mysore Bonda\n\n#### 2. **Description**  \n> M...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Mysore Bonda is a popular South Indian snack m...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India                True               False               False
#
#               Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Healthy, Gluten-Free        5  ...       6           0      0
#
#   Saturated Fat  Sugar        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0             0      0  Deep Fried                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Aval Mixture (Beaten Rice Snack)

#### 2. **Description**  
> Aval Mixture is a light and crunchy South Indian snack made from beaten rice, peanuts, and a variety of spices. It is often served as a tea-time snack and is easy to prepare with pantry staples.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 2 cups beaten rice (aval)
  - 1/4 cup peanuts
  - 1 tbsp oil
  - 1/2 tsp mustard seeds
  - 1/4 tsp turmeric powder
  - 1/2 tsp red chili powder
  - Salt (to taste)
  - A few curry leaves
  - 1/2 tsp hing (asafoetida)
  - 1 tbsp sesame seeds (optional)
  - 1 tbsp dry coconut (optional)
  
---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 10-15 minutes  
- **Total Time:** ~25 minutes  

---

#### 5. **How to Prepare**  
1. Heat oil in a pan and add mustard seeds. Let them splutter.  
2. Add peanuts and fry them until they become crispy.  
3. Add curry leaves, turmeric powder, red chili powder, and hing. Sauté for a minute.  
4. Add the beaten rice (aval) and mix well. Ensure it is evenly coated with the spice mix.  
5. Add salt, sesame seeds (optional), and dry coconut (optional). Toss everything together.  
6. Serve the Aval Mixture hot or at room temperature as a crunchy snack.

---

#### 6. **Tips**  
- Add roasted chickpeas or roasted cashews for additional crunch.  
- For a slightly sweeter version, add jaggery or sugar to the mixture.

---

#### 7. **Serving Suggestions**  
- Aval Mixture can be served as a quick snack with a cup of tea or coffee.  
- It can also be packed for travel or picnics.

---

#### 8. **Nutritional Information**  
- **Calories:** 150 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 25 g  
- **Fat:** 6 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # If no match, assign an empty string

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",  # Add a link/photo path if available
    "Region": "South India",
    "Time of Eating (B)": False,  
    "Time of Eating (L)": True,  # Example for lunch
    "Time of Eating (D)": True,  # Example for dinner
    "Food Type": "Light Snack",
    "Ratings": 4,
    "Cholesterol": 0,
    "Sodium": 200,  # Approximation
    "Saturated Fat": 0.5,  # Approximation
    "Sugar": 1,  # Approximation
    "Type": "Fried/Crunchy",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": np.nan
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Aval Mixture (Beaten Rice Snack)\n\n#### 2. **...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Aval Mixture is a light and crunchy South Indi...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False                True                True
#
#      Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  Sugar  \
# 0  Light Snack        4  ...       4           0    200           0.5      1
#
#             Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0  Fried/Crunchy                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Aval Mixture (Beaten Rice Snack)\n\n#### 2. **...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Aval Mixture is a light and crunchy South Indi...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False                True                True
#
#      Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  Sugar  \
# 0  Light Snack        4  ...       4           0    200           0.5      1
#
#             Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0  Fried/Crunchy                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    NaN
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Aloo Bajji
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Aloo Bajji

#### 2. **Description**  
> Aloo Bajji is a popular snack from India made by dipping spiced mashed potato filling in a chickpea flour batter and deep frying. It's crispy on the outside and soft inside, often enjoyed with chutneys or as a part of street food.

---

#### 3. **Ingredients**  
- **For Stuffing:**
  - 3 large potatoes, boiled and mashed
  - 1 tsp mustard seeds
  - 1/4 tsp turmeric powder
  - 1 tsp garam masala
  - 1-2 green chilies, chopped
  - 1 tsp ginger-garlic paste
  - Salt to taste
  - Fresh coriander leaves, chopped
- **For Batter:**
  - 1 cup chickpea flour (besan)
  - 1/4 tsp turmeric powder
  - 1/2 tsp red chili powder
  - Salt to taste
  - Water (to make the batter)
  - A pinch of baking soda (optional)
- **For Frying:**
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15-20 minutes  
- **Cooking Time:** 10-12 minutes  
- **Total Time:** ~30 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Stuffing: Heat a little oil in a pan, add mustard seeds, and let them splutter. Then, add chopped green chilies, ginger-garlic paste, and sauté for a minute. Add turmeric powder, garam masala, and mashed potatoes, and mix well. Add salt and fresh coriander leaves. Set aside to cool.
2. Prepare Batter: In a bowl, combine chickpea flour, turmeric powder, red chili powder, and salt. Gradually add water to make a smooth batter with a consistency that will coat the potato mixture.
3. Shape and Coat: Take a small portion of the potato filling, shape it into a ball or oval, and dip it into the prepared batter, making sure it's fully coated.
4. Deep Fry: Heat oil in a pan or wok on medium heat. Once the oil is hot, gently drop the coated potato balls into the oil and fry until golden brown and crispy. Fry a few at a time to avoid overcrowding.
5. Drain and Serve: Remove from the oil and place on a paper towel to drain excess oil. Serve hot with tamarind chutney or mint chutney.

---

#### 6. **Tips**  
- Add a pinch of ajwain (carom seeds) to the stuffing for added flavor.  
- Adjust the spice levels in the batter as per your taste.  
- To make the bajjis less oily, make sure the oil is hot enough before frying.

---

#### 7. **Serving Suggestions**  
- Serve hot with chutneys such as tamarind or mint chutney.  
- Enjoy as a snack or as part of an evening meal with a cup of tea.

---

#### 8. **Nutritional Information**  
- **Calories:** 250 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 35 g  
- **Fat:** 12 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # If no match, assign a default value ("N/A")

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or N/A
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", "N/A"),
    "Photo": "N/A",
    "Region": "India",
    "Time of Eating (B)": False,  # Not typically eaten for breakfast
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # A popular evening snack
    "Food Type": "Fried, Crispy",
    "Ratings": 4,
    "Cholesterol": "N/A",
    "Sodium": "N/A",
    "Saturated Fat": "N/A",
    "Sugar": "N/A",
    "Type": "Deep Fried",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "N/A"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Aloo Bajji\n\n#### 2. **Description**  \n> Alo...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Aloo Bajji is a popular snack from India made ...                N/A   N/A
#
#   Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  India               False               False                True
#
#        Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat Sugar  \
# 0  Fried, Crispy        4  ...       5         N/A    N/A           N/A   N/A
#
#          Type Food Type (Veg/Non-Veg/Vegan)  \
# 0  Deep Fried                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                             Snack  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    N/A
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Aloo Bajji\n\n#### 2. **Description**  \n> Alo...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Aloo Bajji is a popular snack from India made ...                N/A   N/A
#
#   Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  India               False               False                True
#
#        Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat Sugar  \
# 0  Fried, Crispy        4  ...       5         N/A    N/A           N/A   N/A
#
#          Type Food Type (Veg/Non-Veg/Vegan)  \
# 0  Deep Fried                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                             Snack  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    N/A
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Vazhakkai Bajji (Raw Banana Fritters)

#### 2. **Description**  
> Vazhakkai Bajji is a popular South Indian snack made from raw banana slices dipped in a spicy chickpea flour batter and deep-fried until golden and crispy. It is a delicious snack commonly enjoyed with chutneys or sambar, especially during the monsoon.

---

#### 3. **Ingredients**  
- **For Batter:**
  - 1 cup chickpea flour (besan)
  - 1/4 tsp rice flour
  - 1/4 tsp red chili powder
  - 1/4 tsp turmeric powder
  - 1/4 tsp cumin seeds
  - A pinch of asafoetida (hing)
  - Salt (to taste)
  - Water (to make a thick batter)
- **For Fritters:**
  - 2-3 raw bananas (vazhakkai)
  - Oil (for deep frying)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10-15 minutes (for preparing batter and slicing banana)  
- **Cooking Time:** 5-8 minutes (for frying)  
- **Total Time:** ~20 minutes  

---

#### 5. **How to Prepare**  
1. Slice the raw bananas into thin round pieces, removing the skin.
2. In a bowl, mix chickpea flour, rice flour, red chili powder, turmeric powder, cumin seeds, asafoetida, and salt. Gradually add water to form a thick batter.
3. Heat oil in a deep frying pan on medium heat. 
4. Dip each banana slice into the batter, coating it well, and gently drop them into the hot oil.
5. Fry the fritters until they turn golden brown and crispy. Remove them from oil and drain excess oil on a paper towel.
6. Serve hot with coconut chutney or sambar.

---

#### 6. **Tips**  
- Adjust the consistency of the batter by adding more water if necessary.  
- For extra crispy bajjis, add a pinch of baking soda to the batter.
- If the oil is too hot, the fritters might burn quickly, so maintain medium heat.

---

#### 7. **Serving Suggestions**  
- Serve with tamarind chutney or sambar for a traditional touch.  
- You can also enjoy it with a yogurt dip for added richness.

---

#### 8. **Nutritional Information**  
- **Calories:** 250 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 38 g  
- **Fat:** 12 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # Replacing NaN with a placeholder value

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or placeholders
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "N/A",  # Placeholder for photo
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Example for dinner
    "Food Type": "Crispy, Fried",
    "Ratings": 4,  # Placeholder rating
    "Cholesterol": 0,  # Placeholder for cholesterol
    "Sodium": 0,  # Placeholder for sodium
    "Saturated Fat": 0,  # Placeholder for saturated fat
    "Sugar": 0,  # Placeholder for sugar
    "Type": "Deep Fried Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Snack",
    "Category (Diabetic/BP)": "Not Suitable",
    "Category (Muscle Gain)": "Not Suitable"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Vazhakkai Bajji (Raw Banana Fritters)\n\n#### ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Vazhakkai Bajji is a popular South Indian snac...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False               False                True
#
#        Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Crispy, Fried        4  ...       4           0      0             0
#
#    Sugar             Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Deep Fried Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack           Not Suitable
#
#   Category (Muscle Gain)
# 0           Not Suitable
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Vazhakkai Bajji (Raw Banana Fritters)\n\n#### ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Vazhakkai Bajji is a popular South Indian snac...                N/A   N/A
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False               False                True
#
#        Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  \
# 0  Crispy, Fried        4  ...       4           0      0             0
#
#    Sugar             Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0      0  Deep Fried Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Snack           Not Suitable
#
#   Category (Muscle Gain)
# 0           Not Suitable
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Murungai Keerai Soup (Drumstick Leaf Soup)

#### 2. **Description**  
> A nourishing and flavorful soup made from fresh drumstick leaves, Murungai Keerai Soup is a South Indian favorite. It is highly nutritious and is often consumed to boost immunity and promote overall health.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 1 cup drumstick leaves (fresh, washed, and chopped)
  - 1 medium onion (finely chopped)
  - 2 garlic cloves (minced)
  - 1 small tomato (chopped)
  - 1/2 tsp black pepper powder
  - 1/2 tsp cumin powder
  - 4 cups water
- **For Tempering:**
  - 1 tsp oil or ghee
  - 1/2 tsp mustard seeds
  - A pinch of asafoetida
  - Curry leaves (optional)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 15 minutes  
- **Total Time:** 25 minutes  

---

#### 5. **How to Prepare**  
1. Heat oil or ghee in a pan and add mustard seeds. Let them splutter.  
2. Add asafoetida, curry leaves (if using), chopped onions, and garlic. Sauté until the onions turn translucent.  
3. Add tomatoes and cook until soft.  
4. Add drumstick leaves and sauté for a minute.  
5. Pour in water, add cumin powder and black pepper powder, and mix well. Simmer for 10 minutes.  
6. Strain the soup if preferred or serve as is with the drumstick leaves for added nutrition.

---

#### 6. **Tips**  
- You can add a splash of lemon juice before serving for added tanginess.  
- Use pressure cooking to speed up the process.

---

#### 7. **Serving Suggestions**  
- Serve hot as an appetizer or enjoy it with rice.  
- Garnish with a pinch of black pepper and a few fresh drumstick leaves.  

---

#### 8. **Nutritional Information**  
- **Calories:** 60 kcal  
- **Protein:** 3 g  
- **Carbohydrates:** 5 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Not Applicable"  # Provide a default string instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with complete default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Link to an image or 'Not Applicable'",
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Example for lunch
    "Time of Eating (D)": True,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": 150,
    "Saturated Fat": 0.5,
    "Sugar": 1,
    "Type": "Soup",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Appetizer",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": True
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Murungai Keerai Soup (Drumstick Leaf Soup)\n\n...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  A nourishing and flavorful soup made from fres...     Not Applicable
#
#                                   Photo       Region  Time of Eating (B)  \
# 0  Link to an image or 'Not Applicable'  South India               False
#
#    Time of Eating (L)  Time of Eating (D)             Food Type  Ratings  ...  \
# 0                True                True  Healthy, Gluten-Free      4.5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar  Type  \
# 0       3           0    150           0.5      1  Soup
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Appetizer      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                   True
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Murungai Keerai Soup (Drumstick Leaf Soup)\n\n...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  A nourishing and flavorful soup made from fres...     Not Applicable
#
#                                   Photo       Region  Time of Eating (B)  \
# 0  Link to an image or 'Not Applicable'  South India               False
#
#    Time of Eating (L)  Time of Eating (D)             Food Type  Ratings  ...  \
# 0                True                True  Healthy, Gluten-Free      4.5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar  Type  \
# 0       3           0    150           0.5      1  Soup
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                          Appetizer      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                   True
# ...

# %%
import pandas as pd

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Sambar

#### 2. **Description**  
> Sambar is a flavorful South Indian lentil stew made with tamarind, vegetables, and aromatic spices. It is a staple dish, often served with rice, idli, dosa, or vada.

---

#### 3. **Ingredients**  
- **For Sambar:**
  - 1 cup toor dal (split pigeon peas)
  - 2 cups mixed vegetables (carrot, drumstick, pumpkin, etc.)
  - 2 medium tomatoes, chopped
  - 1 medium onion, chopped
  - 2 tbsp tamarind pulp
  - 1/2 tsp turmeric powder
  - 2 tbsp sambar powder
  - 4-5 curry leaves
  - 2 tbsp oil or ghee
  - Salt (to taste)
- **For Tempering:**
  - 1 tsp mustard seeds
  - 1/2 tsp cumin seeds
  - 2 dried red chilies
  - 1/4 tsp asafoetida (hing)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 30 minutes  
- **Total Time:** 45 minutes  

---

#### 5. **How to Prepare**  
1. **Cook the Dal:** Wash the toor dal thoroughly, pressure cook it with turmeric powder and 3 cups of water until soft and mushy. Mash and set aside.  
2. **Prepare Tamarind Water:** Soak tamarind pulp in warm water for 10 minutes and extract the juice.  
3. **Cook Vegetables:** In a pot, add mixed vegetables, onions, tomatoes, tamarind water, salt, and sambar powder. Cook until vegetables are tender.  
4. **Combine Dal and Vegetables:** Add cooked dal to the vegetable mixture and mix well. Simmer for 10 minutes.  
5. **Prepare Tempering:** Heat oil or ghee, add mustard seeds, cumin seeds, red chilies, asafoetida, and curry leaves. Pour the tempering over the sambar and mix.  
6. **Serve:** Garnish with fresh coriander leaves and serve hot.

---

#### 6. **Tips**  
- Add a teaspoon of jaggery for a subtle sweetness.  
- Adjust the consistency of sambar by adding water as needed.  

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice, idli, dosa, or vada.  
- Top with a dollop of ghee for extra flavor.  

---

#### 8. **Nutritional Information**  
- **Calories:** 150 kcal  
- **Protein:** 7 g  
- **Carbohydrates:** 22 g  
- **Fat:** 4 g  
"""

# Pre-defined data for Sambar with no null values
data = {
    "Name": "Sambar",
    "Desc (Kirusa type of writing)": "Sambar is a flavorful South Indian lentil stew made with tamarind, vegetables, and aromatic spices. It is a staple dish, often served with rice, idli, dosa, or vada.",
    "Desc (Preparation)": "Cook the dal with turmeric. Soak tamarind, cook vegetables, and mix with dal. Add tempering and simmer.",
    "Photo": "sambar.jpg",  # Example: an image file name
    "Region": "South India",
    "Time of Eating (B)": True,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Nutritious, Comfort Food",
    "Ratings": 5,
    "Ingredients": """- 1 cup toor dal
- 2 cups mixed vegetables
- 2 medium tomatoes
- 1 medium onion
- 2 tbsp tamarind pulp
- 1/2 tsp turmeric
- 2 tbsp sambar powder
- Curry leaves, mustard seeds, etc.""",
    "Calories": 150,
    "Fat": 4,
    "Protein": 7,
    "Cholesterol": 0,
    "Sodium": 300,  # Estimated based on seasoning
    "Saturated Fat": 1,
    "Sugar": 4,
    "Type": "Stew",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": True
}

# Convert the data into a DataFrame
columns = list(data.keys())
df = pd.DataFrame([data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#      Name                      Desc (Kirusa type of writing)  \
# 0  Sambar  Sambar is a flavorful South Indian lentil stew...
#
#                                   Desc (Preparation)       Photo       Region  \
# 0  Cook the dal with turmeric. Soak tamarind, coo...  sambar.jpg  South India
#
#    Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0                True                True                True
#
#                   Food Type  Ratings  ... Protein  Cholesterol  Sodium  \
# 0  Nutritious, Comfort Food        5  ...       7            0     300
#
#    Saturated Fat  Sugar  Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0              1      4  Stew                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                   True
#
# [1 rows x 23 columns]

# %%
df
# Out:
#      Name                      Desc (Kirusa type of writing)  \
# 0  Sambar  Sambar is a flavorful South Indian lentil stew...
#
#                                   Desc (Preparation)       Photo       Region  \
# 0  Cook the dal with turmeric. Soak tamarind, coo...  sambar.jpg  South India
#
#    Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0                True                True                True
#
#                   Food Type  Ratings  ... Protein  Cholesterol  Sodium  \
# 0  Nutritious, Comfort Food        5  ...       7            0     300
#
#    Saturated Fat  Sugar  Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0              1      4  Stew                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                   True
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Rasam

#### 2. **Description**  
> Rasam is a tangy and spiced South Indian soup made with tamarind, tomatoes, and aromatic spices. It is often served as a comforting starter or paired with steamed rice.

---

#### 3. **Ingredients**  
- **For Rasam:**
  - 1 lemon-sized ball of tamarind
  - 2 medium tomatoes (chopped)
  - 2 cups water
  - 1/2 tsp turmeric powder
  - Salt (to taste)
- **For Tempering:**
  - 1 tsp oil
  - 1 tsp mustard seeds
  - 1/4 tsp asafoetida
  - A few curry leaves
- **Spices:**
  - 1 tsp black pepper (coarsely ground)
  - 1 tsp cumin seeds (coarsely ground)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** 35 minutes  

---

#### 5. **How to Prepare**  
1. Soak the tamarind in water for 10 minutes. Extract the juice and discard the pulp.  
2. Heat oil in a pan. Add mustard seeds, curry leaves, and asafoetida. Let them crackle.  
3. Add tomatoes and sauté until softened.  
4. Pour in tamarind juice, add water, turmeric powder, salt, and let it simmer.  
5. Add coarsely ground pepper and cumin. Boil for 5 minutes.  
6. Serve hot, garnished with fresh coriander leaves.

---

#### 6. **Tips**  
- Add a pinch of jaggery for a hint of sweetness.  
- For a richer flavor, use homemade rasam powder instead of just cumin and pepper.  

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice and papadam for a complete meal.  
- Can be enjoyed as a soup on colder days.

---

#### 8. **Nutritional Information**  
- **Calories:** 80 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 12 g  
- **Fat:** 2 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else ""

# Fill additional columns with default values (no nulls)
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "rasam_photo_url",  # Placeholder for an image
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Tangy, Light, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 30,  # Assumed value
    "Saturated Fat": 0.1,  # Assumed value
    "Sugar": 2,  # Assumed value
    "Type": "Soup",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch/Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Muscle Recovery"
})

# Columns for the DataFrame
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Create DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Rasam\n\n#### 2. **Description**  \n> Rasam is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Rasam is a tangy and spiced South Indian soup ...
#
#              Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  rasam_photo_url  South India               False                True
#
#    Time of Eating (D)                  Food Type  Ratings  ... Protein  \
# 0                True  Tangy, Light, Gluten-Free        5  ...       2
#
#   Cholesterol Sodium Saturated Fat  Sugar  Type  \
# 0           0     30           0.1      2  Soup
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Muscle Recovery
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Rasam\n\n#### 2. **Description**  \n> Rasam is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Rasam is a tangy and spiced South Indian soup ...
#
#              Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  rasam_photo_url  South India               False                True
#
#    Time of Eating (D)                  Food Type  Ratings  ... Protein  \
# 0                True  Tangy, Light, Gluten-Free        5  ...       2
#
#   Cholesterol Sodium Saturated Fat  Sugar  Type  \
# 0           0     30           0.1      2  Soup
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Muscle Recovery
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Avial
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Avial

#### 2. **Description**  
> Avial is a traditional mixed vegetable curry from Kerala. It is known for its unique coconut-based flavor and the addition of curd, making it a mild and creamy side dish.

---

#### 3. **Ingredients**  
- **Vegetables:**
  - 1 cup raw banana (cut into pieces)
  - 1 cup carrot (cut into pieces)
  - 1 cup beans (cut into pieces)
  - 1 cup ash gourd (cut into pieces)
- **For Coconut Mixture:**
  - 1 cup grated coconut
  - 2-3 green chilies
  - 1 tsp cumin seeds
  - 2 tbsp curd
- **Others:**
  - 2 tbsp coconut oil
  - A few curry leaves
  - Salt (to taste)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 20-25 minutes  
- **Total Time:** ~45 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Vegetables: Wash, peel, and cut the vegetables into even-sized pieces.  
2. Cook Vegetables: Boil the vegetables with a little salt until tender but firm. Do not overcook.  
3. Prepare Coconut Mixture: Grind the coconut, green chilies, and cumin seeds into a coarse paste.  
4. Add Coconut Mixture: Add the coconut paste to the cooked vegetables and mix well. Cook for 3-5 minutes on low heat.  
5. Finish with Curd: Add the curd and mix gently. Remove from heat.  
6. Garnish: Drizzle coconut oil on top, add curry leaves, and mix. Serve hot.  

---

#### 6. **Tips**  
- Do not overcook the vegetables to maintain their texture.  
- Adjust the spice level by increasing or decreasing green chilies.  

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice and papad.  
- Goes well as a side dish for traditional Kerala sadya.

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 25 g  
- **Fat:** 8 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # Assign placeholder for missing values

# Add non-recipe attributes with no null values
additional_data = {
    "Desc (Preparation)": extracted_data.get("How to Prepare", "N/A"),
    "Photo": "https://example.com/avial.jpg",  # Placeholder image URL
    "Region": "Kerala",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Typically eaten at lunch
    "Time of Eating (D)": False,
    "Food Type": "Healthy, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 0,
    "Saturated Fat": 3,
    "Sugar": 2,
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Protein-Rich"
}

# Merge extracted and additional data
final_data = {**extracted_data, **additional_data}

# Prepare columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert data to DataFrame
df = pd.DataFrame([final_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Avial\n\n#### 2. **Description**  \n> Avial is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Avial is a traditional mixed vegetable curry f...                N/A
#
#                            Photo  Region  Time of Eating (B)  \
# 0  https://example.com/avial.jpg  Kerala               False
#
#    Time of Eating (L)  Time of Eating (D)             Food Type  Ratings  ...  \
# 0                True               False  Healthy, Gluten-Free        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0       4           0      0             3      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Lunch      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           Protein-Rich
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Avial\n\n#### 2. **Description**  \n> Avial is...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Avial is a traditional mixed vegetable curry f...                N/A
#
#                            Photo  Region  Time of Eating (B)  \
# 0  https://example.com/avial.jpg  Kerala               False
#
#    Time of Eating (L)  Time of Eating (D)             Food Type  Ratings  ...  \
# 0                True               False  Healthy, Gluten-Free        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0       4           0      0             3      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Lunch      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           Protein-Rich
#
# ...

# %%
import pandas as pd
import re

# Recipe text for Vatha Kuzhambu
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Vatha Kuzhambu

#### 2. **Description**  
> Vatha Kuzhambu is a tangy and spicy South Indian tamarind-based curry. It is made with vegetables or dried berries (sundakkai) and is best enjoyed with steamed rice.

---

#### 3. **Ingredients**  
- **For Kuzhambu:**
  - 1 lemon-sized ball of tamarind
  - 2 tbsp sesame oil
  - 1 tsp mustard seeds
  - 1 tsp fenugreek seeds
  - 10 curry leaves
  - 1 dried red chili
  - 2 tbsp sambar powder
  - 1/2 tsp turmeric powder
  - 1/4 cup small onions or shallots (peeled)
  - 2 tbsp dried sundakkai (optional)
  - 1 tsp jaggery
  - Salt (to taste)
  - Water (as required)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** 30 minutes  

---

#### 5. **How to Prepare**  
1. Soak the tamarind in warm water for 10 minutes and extract the juice.  
2. Heat sesame oil in a pan. Add mustard seeds, fenugreek seeds, dried red chili, and curry leaves. Sauté until aromatic.  
3. Add small onions and sundakkai (if using). Sauté until the onions turn golden.  
4. Mix in turmeric powder, sambar powder, and tamarind juice. Add required water and bring to a boil.  
5. Simmer until the curry thickens and the flavors are well blended. Add jaggery and salt to taste.  
6. Serve hot with steamed rice.

---

#### 6. **Tips**  
- Add brinjal or drumsticks as a variation to the dish.  
- For an extra punch of flavor, dry roast and grind 1 tsp of coriander seeds and fenugreek seeds.

---

#### 7. **Serving Suggestions**  
- Serve with hot steamed rice and a dollop of ghee.  
- Pair it with appalam (papad) or kootu as a side dish.

---

#### 8. **Nutritional Information**  
- **Calories:** 150 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 14 g  
- **Fat:** 8 g  
"""

# Regex patterns for extraction
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not Provided"

# Filling additional data manually to ensure no null values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", "Not Provided"),
    "Photo": "image_vatha_kuzhambu.jpg",  # Example placeholder image
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Commonly eaten for lunch
    "Time of Eating (D)": True,
    "Food Type": "Tangy, Spicy",
    "Ratings": 4.7,
    "Cholesterol": 0,
    "Sodium": 5,
    "Saturated Fat": 1,
    "Sugar": 2,
    "Type": "Curry Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": False
})

# Define columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Vatha Kuzhambu\n\n#### 2. **Description**  \n>...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Vatha Kuzhambu is a tangy and spicy South Indi...       Not Provided
#
#                       Photo       Region  Time of Eating (B)  \
# 0  image_vatha_kuzhambu.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)     Food Type  Ratings  ... Protein  \
# 0                True                True  Tangy, Spicy      4.7  ...       2
#
#   Cholesterol Sodium Saturated Fat  Sugar        Type  \
# 0           0      5             1      2  Curry Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                  False
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Vatha Kuzhambu\n\n#### 2. **Description**  \n>...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Vatha Kuzhambu is a tangy and spicy South Indi...       Not Provided
#
#                       Photo       Region  Time of Eating (B)  \
# 0  image_vatha_kuzhambu.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)     Food Type  Ratings  ... Protein  \
# 0                True                True  Tangy, Spicy      4.7  ...       2
#
#   Cholesterol Sodium Saturated Fat  Sugar        Type  \
# 0           0      5             1      2  Curry Dish
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                  False
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Puli Kuzhambu (Tamarind Curry)

#### 2. **Description**  
> Puli Kuzhambu is a tangy and flavorful South Indian curry made using tamarind, spices, and vegetables like okra or eggplant. This dish is a staple in Tamil Nadu and pairs perfectly with steamed rice.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 1 lemon-sized ball of tamarind
  - 1 cup chopped vegetables (okra, eggplant, or drumstick)
  - 2 tbsp sesame oil
  - 1 tsp mustard seeds
  - 1 sprig curry leaves
  - 1 medium onion, finely chopped
  - 2 tomatoes, finely chopped
- **Spices and Seasoning:**
  - 1 tsp turmeric powder
  - 2 tsp red chili powder
  - 1 tsp coriander powder
  - 1/2 tsp fenugreek seeds
  - Salt to taste
- **For Grinding:**
  - 2 tsp grated coconut
  - 1 tsp cumin seeds
  - 2 small garlic cloves

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 25 minutes  
- **Total Time:** 45 minutes  

---

#### 5. **How to Prepare**  
1. Soak the tamarind in a cup of warm water for 10 minutes. Extract the pulp and set it aside.  
2. Grind the grated coconut, cumin seeds, and garlic into a smooth paste using a little water.  
3. Heat sesame oil in a pan, add mustard seeds, and let them splutter. Add fenugreek seeds, curry leaves, and onion. Sauté until onions turn golden.  
4. Add tomatoes and cook until mushy. Then, add turmeric, red chili, and coriander powders. Mix well.  
5. Add the chopped vegetables and sauté for a few minutes. Pour in the tamarind extract, ground coconut paste, and 1-1.5 cups of water. Bring to a boil.  
6. Simmer the curry for 15-20 minutes until the vegetables are cooked and the curry thickens.  
7. Serve hot with steamed rice and a drizzle of sesame oil for an authentic flavor.

---

#### 6. **Tips**  
- Add a small piece of jaggery for a mild sweetness to balance the tanginess.  
- You can use any combination of vegetables like okra, eggplant, or even just shallots.  

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice and papad for a complete meal.  
- Pair it with poriyal (stir-fried vegetables) or appalam (crispy papad) for a traditional spread.  

---

#### 8. **Nutritional Information**  
- **Calories:** 120 kcal  
- **Protein:** 3 g  
- **Carbohydrates:** 18 g  
- **Fat:** 5 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "N/A"

# Fill additional columns with valid values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Available",  # Simulated placeholder value
    "Region": "Tamil Nadu, South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Tangy, Flavorful",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": 200,
    "Saturated Fat": 1,
    "Sugar": 3,
    "Type": "Curry Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch/Dinner",
    "Category (Diabetic/BP)": "Low in Cholesterol",
    "Category (Muscle Gain)": "N/A"
})

# Define DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert the data to a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Puli Kuzhambu (Tamarind Curry)\n\n#### 2. **De...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Puli Kuzhambu is a tangy and flavorful South I...                N/A
#
#        Photo                   Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available  Tamil Nadu, South India               False                True
#
#    Time of Eating (D)         Food Type  Ratings  ... Protein Cholesterol  \
# 0                True  Tangy, Flavorful      4.5  ...       3           0
#
#   Sodium Saturated Fat  Sugar        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    200             1      3  Curry Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner     Low in Cholesterol
#
#   Category (Muscle Gain)
# 0                    N/A
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Puli Kuzhambu (Tamarind Curry)\n\n#### 2. **De...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Puli Kuzhambu is a tangy and flavorful South I...                N/A
#
#        Photo                   Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available  Tamil Nadu, South India               False                True
#
#    Time of Eating (D)         Food Type  Ratings  ... Protein Cholesterol  \
# 0                True  Tangy, Flavorful      4.5  ...       3           0
#
#   Sodium Saturated Fat  Sugar        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    200             1      3  Curry Dish                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner     Low in Cholesterol
#
#   Category (Muscle Gain)
# 0                    N/A
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Mor Kuzhambu (Buttermilk Curry)

#### 2. **Description**  
> Mor Kuzhambu is a traditional South Indian buttermilk curry. This mildly spiced, creamy curry is often served with steamed rice and is perfect for a comforting meal.

---

#### 3. **Ingredients**  
- **For the Curry:**
  - 1 cup buttermilk
  - 1/2 cup water
  - 1/4 tsp turmeric powder
  - 1 tbsp coconut oil
  - Curry leaves (a few)
- **For the Spice Paste:**
  - 1 tbsp cumin seeds
  - 1 tsp rice (soaked)
  - 2 green chilies
  - 1/4 cup grated coconut
  - 1/4 cup soaked chana dal
  - 1/4 tsp mustard seeds

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 10 minutes  
- **Total Time:** 25 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Spice Paste: Grind the soaked rice, coconut, cumin seeds, green chilies, and chana dal into a fine paste with a little water.  
2. Mix Base: Whisk the buttermilk with water, turmeric powder, and the prepared spice paste.  
3. Cook Curry: Heat coconut oil in a pan, add mustard seeds, and let them splutter. Add curry leaves and stir.  
4. Combine: Pour the buttermilk mixture into the pan, stirring continuously on low heat. Avoid boiling.  
5. Finish: Remove from heat when the curry thickens slightly.  

---

#### 6. **Tips**  
- Use fresh buttermilk for the best flavor.  
- Adjust the spice level by adding more or fewer green chilies.

---

#### 7. **Serving Suggestions**  
- Serve Mor Kuzhambu with steamed rice and a dry vegetable side dish like beans poriyal or potato fry.  

---

#### 8. **Nutritional Information**  
- **Calories:** 120 kcal  
- **Protein:** 3 g  
- **Carbohydrates:** 8 g  
- **Fat:** 7 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex and ensure no null values
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "---"  # Default value for missing fields

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default or appropriate values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Available",  # Assume photo is available
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Commonly served for lunch
    "Time of Eating (D)": False,
    "Food Type": "Comfort Food, Gluten-Free",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": 10,  # Estimated sodium in mg
    "Saturated Fat": 3,  # Estimated saturated fat in g
    "Sugar": 2,  # Estimated sugar in g
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch",
    "Category (Diabetic/BP)": "Low Fat",
    "Category (Muscle Gain)": "Protein-Rich"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Mor Kuzhambu (Buttermilk Curry)\n\n#### 2. **D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Mor Kuzhambu is a traditional South Indian but...                ---
#
#        Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available  South India               False                True
#
#    Time of Eating (D)                  Food Type  Ratings  ... Protein  \
# 0               False  Comfort Food, Gluten-Free      4.8  ...       3
#
#   Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0           0     10             3      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Lunch                Low Fat
#
#   Category (Muscle Gain)
# 0           Protein-Rich
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Mor Kuzhambu (Buttermilk Curry)\n\n#### 2. **D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Mor Kuzhambu is a traditional South Indian but...                ---
#
#        Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available  South India               False                True
#
#    Time of Eating (D)                  Food Type  Ratings  ... Protein  \
# 0               False  Comfort Food, Gluten-Free      4.8  ...       3
#
#   Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0           0     10             3      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Lunch                Low Fat
#
#   Category (Muscle Gain)
# 0           Protein-Rich
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Kozhi Kuzhambu (Chicken Curry)

#### 2. **Description**  
> Kozhi Kuzhambu is a traditional South Indian chicken curry cooked with a blend of spices and coconut. This hearty and flavorful dish pairs perfectly with steamed rice, parotta, or idiyappam.

---

#### 3. **Ingredients**  
- **For Curry:**
  - 500 g chicken (cleaned and cut into pieces)
  - 2 onions (finely chopped)
  - 2 tomatoes (pureed)
  - 1 cup coconut milk
  - 2 tbsp ginger-garlic paste
  - 3 tbsp oil
- **For Spice Mix:**
  - 1 tsp turmeric powder
  - 2 tsp red chili powder
  - 1 tbsp coriander powder
  - 1 tsp garam masala
  - Salt (to taste)
- **For Tempering:**
  - 1 tsp mustard seeds
  - 2 dried red chilies
  - A few curry leaves

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 40 minutes  
- **Total Time:** 1 hour  

---

#### 5. **How to Prepare**  
1. Heat oil in a pan, add mustard seeds, red chilies, and curry leaves. Let them splutter.  
2. Add chopped onions and sauté until golden brown. Then add ginger-garlic paste and cook until the raw smell disappears.  
3. Mix in the tomato puree and cook until oil separates.  
4. Add turmeric, chili powder, coriander powder, and salt. Sauté for 2 minutes.  
5. Add chicken pieces, mix well, and cook for 10 minutes.  
6. Pour in coconut milk and simmer for 20-30 minutes until the chicken is tender and the curry thickens.  
7. Add garam masala and stir. Simmer for 2 minutes. Serve hot.

---

#### 6. **Tips**  
- Marinate the chicken with salt and turmeric for an enhanced flavor.  
- Add a few drops of lemon juice or garnish with fresh coriander leaves for a zesty finish.

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice, parotta, or idiyappam.  
- Accompany with a side of cucumber raita or onion salad.

---

#### 8. **Nutritional Information**  
- **Calories:** 250 kcal  
- **Protein:** 25 g  
- **Carbohydrates:** 10 g  
- **Fat:** 15 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "Data not available"

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Available in gallery",
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Rich in protein",
    "Ratings": 4.8,
    "Cholesterol": 70,
    "Sodium": 120,
    "Saturated Fat": 4,
    "Sugar": 3,
    "Type": "Spicy Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Non-Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch/Dinner",
    "Category (Diabetic/BP)": "Moderation Recommended",
    "Category (Muscle Gain)": "High Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Kozhi Kuzhambu (Chicken Curry)\n\n#### 2. **De...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Kozhi Kuzhambu is a traditional South Indian c...  Data not available
#
#                   Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available in gallery  South India               False                True
#
#    Time of Eating (D)        Food Type  Ratings  ... Protein Cholesterol  \
# 0                True  Rich in protein      4.8  ...      25          70
#
#   Sodium Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    120             4      3  Spicy Curry                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner  Moderation Recommended
#
#   Category (Muscle Gain)
# 0           High Protein
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Kozhi Kuzhambu (Chicken Curry)\n\n#### 2. **De...
#
#                        Desc (Kirusa type of writing)  Desc (Preparation)  \
# 0  Kozhi Kuzhambu is a traditional South Indian c...  Data not available
#
#                   Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Available in gallery  South India               False                True
#
#    Time of Eating (D)        Food Type  Ratings  ... Protein Cholesterol  \
# 0                True  Rich in protein      4.8  ...      25          70
#
#   Sodium Saturated Fat  Sugar         Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    120             4      3  Spicy Curry                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages)  Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner  Moderation Recommended
#
#   Category (Muscle Gain)
# 0           High Protein
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Erissery (Pumpkin Curry)
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Erissery (Pumpkin Curry)

#### 2. **Description**  
> Erissery is a flavorful traditional Kerala curry made with pumpkin, coconut, and a blend of spices. It is often part of the festive Onam Sadhya meal and is cherished for its sweet and savory flavors.

---

#### 3. **Ingredients**  
- **For Curry:**
  - 2 cups pumpkin, diced
  - 1/2 cup grated coconut
  - 2 green chilies, chopped
  - 1/4 tsp turmeric powder
  - 1/2 tsp cumin seeds
  - Salt to taste
- **For Tempering:**
  - 2 tbsp coconut oil
  - 1/2 tsp mustard seeds
  - 1 sprig curry leaves
  - 2 dried red chilies
  - 1 tbsp grated coconut (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** 35 minutes  

---

#### 5. **How to Prepare**  
1. Boil the pumpkin with turmeric powder, salt, and a little water until tender.  
2. Grind grated coconut, green chilies, and cumin seeds into a coarse paste.  
3. Add the coconut paste to the cooked pumpkin. Simmer for 5-7 minutes.  
4. In a pan, heat coconut oil and temper mustard seeds, curry leaves, dried red chilies, and grated coconut.  
5. Pour the tempering over the curry. Mix well and serve hot.

---

#### 6. **Tips**  
- Roast the grated coconut slightly for a deeper flavor before grinding.  
- Use ripe pumpkin for the best taste.  

---

#### 7. **Serving Suggestions**  
- Serve Erissery with steamed rice or as a side dish in a traditional Kerala feast.

---

#### 8. **Nutritional Information**  
- **Calories:** 120 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 12 g  
- **Fat:** 8 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else ""

# Fill additional columns with default values or required values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "N/A",  # Placeholder for the photo
    "Region": "Kerala",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Often a lunch dish
    "Time of Eating (D)": True,
    "Food Type": "Traditional, Festive, Healthy",
    "Ratings": 4.8,  # Example rating
    "Cholesterol": 0,
    "Sodium": 5,  # Approximate value in mg
    "Saturated Fat": 2.5,  # Approximate value in g
    "Sugar": 3,  # Approximate value in g
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch/Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Muscle Gain Friendly"
})

# Define column order
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Create DataFrame with no null values
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Erissery (Pumpkin Curry)\n\n#### 2. **Descript...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Erissery is a flavorful traditional Kerala cur...                      N/A
#
#    Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  Kerala               False                True                True
#
#                        Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Traditional, Festive, Healthy      4.8  ...       2           0      5
#
#   Saturated Fat  Sugar   Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0           2.5      3  Curry                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0   Muscle Gain Friendly
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Erissery (Pumpkin Curry)\n\n#### 2. **Descript...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Erissery is a flavorful traditional Kerala cur...                      N/A
#
#    Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  Kerala               False                True                True
#
#                        Food Type  Ratings  ... Protein Cholesterol Sodium  \
# 0  Traditional, Festive, Healthy      4.8  ...       2           0      5
#
#   Saturated Fat  Sugar   Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0           2.5      3  Curry                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                       Lunch/Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0   Muscle Gain Friendly
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Theeyal (Roasted Coconut Curry)

#### 2. **Description**  
> Theeyal is a flavorful South Indian curry made with roasted coconut, tamarind, and spices. Popular in Kerala cuisine, this dish pairs beautifully with steamed rice or appam.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 1 cup grated coconut
  - 2 tbsp coriander seeds
  - 1 tsp cumin seeds
  - 1/2 tsp turmeric powder
  - 2 dried red chilies
  - 2 cups tamarind water
  - 1 cup vegetables (like brinjal, okra, or drumstick) or pearl onions
- **For Tempering:**
  - 2 tbsp coconut oil
  - 1 tsp mustard seeds
  - 2 dried red chilies
  - A few curry leaves

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 30 minutes  
- **Total Time:** 45 minutes  

---

#### 5. **How to Prepare**  
1. Roast the grated coconut, coriander seeds, cumin seeds, turmeric powder, and red chilies in a dry pan until golden brown and fragrant. Let it cool and grind into a fine paste with a little water.  
2. Heat oil in a pan, add mustard seeds, red chilies, and curry leaves. Sauté until aromatic.  
3. Add the chopped vegetables or pearl onions and sauté for 2-3 minutes.  
4. Pour the tamarind water and bring it to a boil. Add the roasted coconut paste, mix well, and cook until the vegetables are soft, and the curry thickens.  
5. Adjust salt and spices to taste. Serve hot.  

---

#### 6. **Tips**  
- Use fresh coconut for the best flavor.  
- You can substitute tamarind with raw mango for a tangy twist.  

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice, appam, or dosa for a traditional Kerala meal.  

---

#### 8. **Nutritional Information**  
- **Calories:** 210 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 20 g  
- **Fat:** 14 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "No Image Available",
    "Region": "Kerala, South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Vegetarian, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 10,
    "Saturated Fat": 9,
    "Sugar": 2,
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": True
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Theeyal (Roasted Coconut Curry)\n\n#### 2. **D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Theeyal is a flavorful South Indian curry made...
#
#                 Photo               Region  Time of Eating (B)  \
# 0  No Image Available  Kerala, South India               False
#
#    Time of Eating (L)  Time of Eating (D)                Food Type  Ratings  \
# 0                True                True  Vegetarian, Gluten-Free        5
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0  ...       4           0     10             9      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                   True
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Theeyal (Roasted Coconut Curry)\n\n#### 2. **D...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Theeyal is a flavorful South Indian curry made...
#
#                 Photo               Region  Time of Eating (B)  \
# 0  No Image Available  Kerala, South India               False
#
#    Time of Eating (L)  Time of Eating (D)                Food Type  Ratings  \
# 0                True                True  Vegetarian, Gluten-Free        5
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0  ...       4           0     10             9      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                   True
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Chettinad Chicken Curry
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Chettinad Chicken Curry

#### 2. **Description**  
> Chettinad Chicken Curry is a rich and aromatic dish from the Chettinad region of Tamil Nadu. It is known for its bold flavors from freshly roasted spices, coconut, and curry leaves, making it a perfect accompaniment to steamed rice or Indian bread.

---

#### 3. **Ingredients**  
- **For Chicken Marinade:**
  - 500g chicken (cut into pieces)
  - 1/2 tsp turmeric powder
  - 1/2 tsp red chili powder
  - 1 tbsp ginger-garlic paste
  - Salt (to taste)
  - 1 tbsp lemon juice
- **For Gravy:**
  - 2 tbsp oil
  - 1 large onion (finely chopped)
  - 2 tomatoes (chopped)
  - 2-3 dried red chilies
  - 1 tbsp ginger-garlic paste
  - 1 tbsp fennel seeds
  - 1/2 tsp cumin seeds
  - 2 tbsp freshly grated coconut
  - 1 tbsp poppy seeds
  - 2-3 cloves
  - 1-inch cinnamon stick
  - 2 bay leaves
  - 1/2 tsp black pepper
  - 1/2 tsp coriander powder
  - 1/2 tsp cumin powder
  - 1/2 tsp garam masala
  - Water (as needed)
  - Fresh cilantro (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 30 minutes  
- **Cooking Time:** 40 minutes  
- **Total Time:** 1 hour 10 minutes  

---

#### 5. **How to Prepare**  
1. Marinade Chicken: In a bowl, mix the chicken with turmeric, red chili powder, ginger-garlic paste, salt, and lemon juice. Set aside for 15-20 minutes.
2. Roast Spices: In a pan, dry roast fennel seeds, cumin seeds, poppy seeds, cloves, cinnamon, and dried red chilies until aromatic. Let it cool, then grind to a fine powder.
3. Cook Onion: Heat oil in a pan and sauté onions until golden brown.
4. Add Tomato and Spices: Add chopped tomatoes, ginger-garlic paste, black pepper, coriander powder, cumin powder, garam masala, and the ground spice mix. Cook until oil separates from the masala.
5. Add Chicken: Add marinated chicken pieces to the pan and cook until they are browned on all sides.
6. Add Coconut and Simmer: Add grated coconut, water, and simmer for 20-30 minutes, allowing the chicken to cook thoroughly and absorb the flavors.
7. Garnish and Serve: Garnish with fresh cilantro and serve hot with rice or Indian bread.

---

#### 6. **Tips**  
- You can add a pinch of sugar to balance the spice.  
- Adjust the water level to control the consistency of the gravy.

---

#### 7. **Serving Suggestions**  
- Serve with steamed rice, chapati, or dosa.  
- Pair with a fresh salad or raita for a complete meal.

---

#### 8. **Nutritional Information**  
- **Calories:** 350 kcal  
- **Protein:** 30 g  
- **Carbohydrates:** 12 g  
- **Fat:** 18 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Empty string instead of NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or empty strings
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare", ""),
    "Photo": "",
    "Region": "Tamil Nadu",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Dinner dish
    "Food Type": "Spicy, Non-Vegetarian",
    "Ratings": "4.5",
    "Cholesterol": "70 mg",  # Approximation
    "Sodium": "200 mg",  # Approximation
    "Saturated Fat": "4 g",  # Approximation
    "Sugar": "2 g",  # Approximation
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Non-Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Dinner",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "Yes"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Chettinad Chicken Curry\n\n#### 2. **Descripti...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Chettinad Chicken Curry is a rich and aromatic...
#
#        Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  Tamil Nadu               False               False                True
#
#                Food Type Ratings  ... Protein Cholesterol  Sodium  \
# 0  Spicy, Non-Vegetarian     4.5  ...      30       70 mg  200 mg
#
#   Saturated Fat Sugar   Type Food Type (Veg/Non-Veg/Vegan)  \
# 0           4 g   2 g  Curry                       Non-Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                            Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    Yes
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Chettinad Chicken Curry\n\n#### 2. **Descripti...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Chettinad Chicken Curry is a rich and aromatic...
#
#        Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  Tamil Nadu               False               False                True
#
#                Food Type Ratings  ... Protein Cholesterol  Sodium  \
# 0  Spicy, Non-Vegetarian     4.5  ...      30       70 mg  200 mg
#
#   Saturated Fat Sugar   Type Food Type (Veg/Non-Veg/Vegan)  \
# 0           4 g   2 g  Curry                       Non-Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                            Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0                    Yes
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re
import numpy as np

# Recipe text for Mutton Sukka
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Mutton Sukka

#### 2. **Description**  
> Mutton Sukka is a flavorful dry mutton dish from South India that is cooked with a spicy masala. It’s a popular side dish typically served with rice or as a starter in many festive occasions.

---

#### 3. **Ingredients**  
- **For Marination:**
  - 500 g mutton (boneless)
  - 1 tbsp ginger-garlic paste
  - 1 tbsp red chili powder
  - 1 tsp turmeric powder
  - Salt to taste
  - 1 tbsp lemon juice
- **For Cooking:**
  - 2 tbsp oil
  - 1 large onion (finely chopped)
  - 2 tomatoes (pureed)
  - 2 green chilies (slit)
  - 1 tbsp coriander powder
  - 1 tsp garam masala
  - 1/2 tsp cumin powder
  - 1/4 tsp black pepper powder
  - Fresh coriander leaves (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 30 minutes (for marinating)  
- **Cooking Time:** 45-60 minutes  
- **Total Time:** ~1 hour 30 minutes  

---

#### 5. **How to Prepare**  
1. Marinate the mutton with ginger-garlic paste, red chili powder, turmeric powder, salt, and lemon juice. Let it rest for 30 minutes.  
2. Heat oil in a pan and sauté the onions until golden brown.  
3. Add the tomatoes and cook until they turn soft.  
4. Add the marinated mutton and cook on medium heat for 5 minutes.  
5. Sprinkle coriander powder, garam masala, cumin powder, and black pepper powder. Mix well.  
6. Cover and cook for 45 minutes to an hour on low heat, until the mutton becomes tender and the masala thickens.  
7. Garnish with fresh coriander leaves and serve hot.

---

#### 6. **Tips**  
- Adjust the cooking time based on the tenderness of the mutton. If necessary, cook longer for a softer texture.  
- You can also add coconut milk for a richer, smoother taste.

---

#### 7. **Serving Suggestions**  
- Serve Mutton Sukka with rice, naan, or chapati.  
- Pair with onion raita for a complete meal.

---

#### 8. **Nutritional Information**  
- **Calories:** 350 kcal  
- **Protein:** 30 g  
- **Carbohydrates:** 10 g  
- **Fat:** 25 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # If no match, assign empty string to avoid null values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",  # No image
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": False,
    "Time of Eating (D)": True,  # Mutton Sukka is typically a dinner dish
    "Food Type": "Spicy, Meat",
    "Ratings": 5,
    "Cholesterol": 70,  # Approx value
    "Sodium": 250,  # Approx value
    "Saturated Fat": 7,  # Approx value
    "Sugar": 3,  # Approx value
    "Type": "Dry Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Non-Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Dinner",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "High Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Mutton Sukka\n\n#### 2. **Description**  \n> M...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Mutton Sukka is a flavorful dry mutton dish fr...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False               False                True
#
#      Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  Sugar  \
# 0  Spicy, Meat        5  ...      30          70    250             7      3
#
#        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0  Dry Dish                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                             Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High Protein
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Mutton Sukka\n\n#### 2. **Description**  \n> M...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Mutton Sukka is a flavorful dry mutton dish fr...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False               False                True
#
#      Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  Sugar  \
# 0  Spicy, Meat        5  ...      30          70    250             7      3
#
#        Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0  Dry Dish                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                             Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           High Protein
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Meen Kuzhambu (Fish Curry)
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Meen Kuzhambu (Fish Curry)

#### 2. **Description**  
> Meen Kuzhambu is a popular South Indian fish curry made with fresh fish, tamarind, and a blend of spices. It's typically served with steamed rice and is known for its tangy, spicy, and flavorful taste.

---

#### 3. **Ingredients**  
- **For Curry:**
  - 500 g fish (any firm white fish like tilapia or seer fish)
  - 2 tbsp oil
  - 1 onion (finely chopped)
  - 2 tomatoes (chopped)
  - 1 tbsp ginger-garlic paste
  - 2-3 green chilies (slit)
  - 1 tsp turmeric powder
  - 1 tsp red chili powder
  - 1 tsp coriander powder
  - 1 tsp cumin powder
  - 1 tbsp tamarind paste
  - Salt to taste
  - 1 cup water
  - Fresh coriander leaves (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 20-25 minutes  
- **Total Time:** ~35 minutes  

---

#### 5. **How to Prepare**  
1. Heat oil in a pan. Add chopped onions and sauté until golden brown.  
2. Add ginger-garlic paste and slit green chilies, and sauté for another 2 minutes.  
3. Add chopped tomatoes and cook until soft.  
4. Add turmeric powder, red chili powder, coriander powder, and cumin powder. Cook for 5 minutes, stirring continuously.  
5. Add tamarind paste, salt, and water. Bring to a boil.  
6. Once the gravy is boiling, add the fish pieces and cook for 10-15 minutes, or until the fish is cooked through and the gravy thickens.  
7. Garnish with fresh coriander leaves. Serve hot with rice.

---

#### 6. **Tips**  
- You can use any firm fish of your choice like seer fish, tilapia, or kingfish for the curry.  
- Adjust the amount of chili powder according to your spice preference.

---

#### 7. **Serving Suggestions**  
- Serve with steamed white rice, dosa, or idli.  
- Pair with coconut chutney for a more flavorful meal.

---

#### 8. **Nutritional Information**  
- **Calories:** 220 kcal  
- **Protein:** 22 g  
- **Carbohydrates:** 10 g  
- **Fat:** 12 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = ""  # Empty string if no match, to avoid NaN

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or non-empty values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "",  # Assuming no photo for this entry
    "Region": "South India",
    "Time of Eating (B)": False,  # Example for breakfast
    "Time of Eating (L)": True,   # Example for lunch
    "Time of Eating (D)": True,   # Example for dinner
    "Food Type": "Spicy, Rich",
    "Ratings": 5,  # Assuming full rating
    "Cholesterol": 30,  # Sample value (adjust based on your source)
    "Sodium": 350,  # Sample value (adjust based on your source)
    "Saturated Fat": 2,  # Sample value (adjust based on your source)
    "Sugar": 5,  # Sample value (adjust based on your source)
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Non-Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "Muscle Gain Friendly"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Meen Kuzhambu (Fish Curry)\n\n#### 2. **Descri...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Meen Kuzhambu is a popular South Indian fish c...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False                True                True
#
#      Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  Sugar  \
# 0  Spicy, Rich        5  ...      22          30    350             2      5
#
#     Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0  Curry                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Lunch  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0   Muscle Gain Friendly
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Meen Kuzhambu (Fish Curry)\n\n#### 2. **Descri...
#
#                        Desc (Kirusa type of writing) Desc (Preparation) Photo  \
# 0  Meen Kuzhambu is a popular South Indian fish c...
#
#         Region  Time of Eating (B)  Time of Eating (L)  Time of Eating (D)  \
# 0  South India               False                True                True
#
#      Food Type  Ratings  ... Protein Cholesterol Sodium Saturated Fat  Sugar  \
# 0  Spicy, Rich        5  ...      22          30    350             2      5
#
#     Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0  Curry                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                              Lunch  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0   Muscle Gain Friendly
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text for Chepala Pulusu (Andhra Fish Curry)
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Chepala Pulusu (Andhra Fish Curry)

#### 2. **Description**  
> Chepala Pulusu is a tangy and spicy fish curry from Andhra Pradesh, cooked with tamarind, spices, and fresh fish. It is a traditional dish enjoyed for lunch or dinner, often paired with steamed rice.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 500 g fish (cleaned and cut into pieces)
  - 2 cups tamarind pulp
  - 2 onions (finely chopped)
  - 3 tomatoes (pureed)
- **Spices:**
  - 2 tbsp red chili powder
  - 1/2 tsp turmeric powder
  - 1 tsp coriander powder
  - 1 tsp cumin powder
  - 1/2 tsp mustard seeds
  - 2 tbsp oil
- **Other:**
  - 1 tbsp garlic paste
  - Curry leaves
  - Salt (to taste)
  - Water (as needed)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 30 minutes  
- **Total Time:** ~50 minutes  

---

#### 5. **How to Prepare**  
1. Heat oil in a pan and splutter mustard seeds. Add curry leaves, garlic paste, and onions. Sauté until golden brown.  
2. Add turmeric, red chili powder, coriander powder, and cumin powder. Cook for a minute.  
3. Stir in tomato puree and cook until oil separates.  
4. Add tamarind pulp, salt, and water. Simmer for 5-7 minutes.  
5. Gently add the fish pieces, cover, and cook for 10-15 minutes, ensuring the fish is cooked and absorbs the flavors.  
6. Serve hot with steamed rice.

---

#### 6. **Tips**  
- Avoid stirring the curry vigorously after adding fish to prevent breaking the pieces.  
- Let the curry rest for an hour before serving to enhance flavors.  

---

#### 7. **Serving Suggestions**  
- Pair with hot steamed rice for a perfect traditional Andhra meal.  
- Serve with sliced onions and lemon wedges on the side.  

---

#### 8. **Nutritional Information**  
- **Calories:** 240 kcal  
- **Protein:** 20 g  
- **Carbohydrates:** 15 g  
- **Fat:** 12 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Value Not Found"  # No null values

# Fill additional columns with values
additional_data = {
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Link to image or placeholder",  # Placeholder for photo
    "Region": "Andhra Pradesh",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Spicy, Traditional",
    "Ratings": 5,
    "Cholesterol": 60,
    "Sodium": 150,
    "Saturated Fat": 3,
    "Sugar": 2,
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Non-Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "Protein Rich"
}
extracted_data.update(additional_data)

# Define DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Chepala Pulusu (Andhra Fish Curry)\n\n#### 2. ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Chepala Pulusu is a tangy and spicy fish curry...    Value Not Found
#
#                           Photo          Region  Time of Eating (B)  \
# 0  Link to image or placeholder  Andhra Pradesh               False
#
#    Time of Eating (L)  Time of Eating (D)           Food Type  Ratings  ...  \
# 0                True                True  Spicy, Traditional        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0      20          60    150             3      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           Protein Rich
#
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Chepala Pulusu (Andhra Fish Curry)\n\n#### 2. ...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Chepala Pulusu is a tangy and spicy fish curry...    Value Not Found
#
#                           Photo          Region  Time of Eating (B)  \
# 0  Link to image or placeholder  Andhra Pradesh               False
#
#    Time of Eating (L)  Time of Eating (D)           Food Type  Ratings  ...  \
# 0                True                True  Spicy, Traditional        5  ...
#
#   Protein Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0      20          60    150             3      2  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0           Protein Rich
#
# ...

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Gongura Mutton Curry

#### 2. **Description**  
> Gongura Mutton Curry is a tangy and spicy delicacy from Andhra Pradesh made with tender mutton and Gongura (sorrel leaves). It is a favorite dish often prepared during special occasions and festivals.

---

#### 3. **Ingredients**  
- **For Curry:**
  - 500 g mutton
  - 2 cups gongura leaves (sorrel leaves)
  - 2 medium onions (chopped)
  - 2 tomatoes (chopped)
  - 1 tbsp ginger-garlic paste
  - 1/2 tsp turmeric powder
  - 1 tbsp red chili powder
  - 1 tsp coriander powder
  - 2-3 green chilies (slit)
  - Salt to taste
- **For Tempering:**
  - 2 tbsp oil
  - 1 tsp mustard seeds
  - 1 tsp cumin seeds
  - 2 dry red chilies
  - 10-12 curry leaves

---

#### 4. **Preparation Time**  
- **Preparation Time:** 30 minutes  
- **Cooking Time:** 1 hour  
- **Total Time:** 1 hour 30 minutes  

---

#### 5. **How to Prepare**  
1. Wash the mutton thoroughly under running water and set it aside.  
2. Heat 1 tbsp oil in a pressure cooker. Add ginger-garlic paste, turmeric, red chili powder, and mutton. Sauté for 5 minutes.  
3. Add 2 cups of water, salt, and pressure cook the mutton until tender (4-5 whistles). Set aside.  
4. In a separate pan, heat the remaining oil and add mustard seeds, cumin seeds, dry red chilies, and curry leaves.  
5. Add onions and sauté until golden brown, then add tomatoes, green chilies, coriander powder, and cooked mutton along with its broth.  
6. Cook for 10 minutes on medium heat, then add chopped gongura leaves. Mix well and cook until the leaves blend into the curry.  
7. Serve hot garnished with fresh coriander leaves.

---

#### 6. **Tips**  
- Use tender goat meat for best results.  
- Adjust the spice levels based on your preference.

---

#### 7. **Serving Suggestions**  
- Serve with hot steamed rice, chapati, or naan.  
- Add a side of onion salad and lemon wedges for an authentic experience.

---

#### 8. **Nutritional Information**  
- **Calories:** 300 kcal  
- **Protein:** 25 g  
- **Carbohydrates:** 5 g  
- **Fat:** 20 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not Available"  # Fallback to "Not Available"

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values or placeholders
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Placeholder for Image URL",
    "Region": "Andhra Pradesh",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Spicy, Tangy",
    "Ratings": 5,
    "Cholesterol": 85,  # Approximate value for mutton-based dishes
    "Sodium": 250,  # Approximate value
    "Saturated Fat": 8,
    "Sugar": 0,
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Non-Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Not Diabetic Friendly",
    "Category (Muscle Gain)": "Rich in Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Gongura Mutton Curry\n\n#### 2. **Description*...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Gongura Mutton Curry is a tangy and spicy deli...      Not Available
#
#                        Photo          Region  Time of Eating (B)  \
# 0  Placeholder for Image URL  Andhra Pradesh               False
#
#    Time of Eating (L)  Time of Eating (D)     Food Type  Ratings  ... Protein  \
# 0                True                True  Spicy, Tangy        5  ...      25
#
#   Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0          85    250             8      0  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Rich in Protein
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Gongura Mutton Curry\n\n#### 2. **Description*...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Gongura Mutton Curry is a tangy and spicy deli...      Not Available
#
#                        Photo          Region  Time of Eating (B)  \
# 0  Placeholder for Image URL  Andhra Pradesh               False
#
#    Time of Eating (L)  Time of Eating (D)     Food Type  Ratings  ... Protein  \
# 0                True                True  Spicy, Tangy        5  ...      25
#
#   Cholesterol Sodium Saturated Fat  Sugar   Type  \
# 0          85    250             8      0  Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                        Non-Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner  Not Diabetic Friendly
#
#   Category (Muscle Gain)
# 0        Rich in Protein
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Kootu Curry

#### 2. **Description**  
> Kootu Curry is a traditional Kerala dish served during festive occasions, especially Onam Sadhya. It is a rich and flavorful curry made with a combination of vegetables, lentils, coconut, and aromatic spices.

---

#### 3. **Ingredients**  
- **For Vegetables:**
  - 1 cup raw banana (cubed)
  - 1 cup yam (cubed)
  - 1/2 tsp turmeric powder
  - Water (for boiling)
- **For Lentils:**
  - 1/2 cup chana dal (split chickpeas), soaked and cooked
- **For Coconut Paste:**
  - 1 cup grated coconut
  - 2 tsp cumin seeds
  - 4-5 green chilies
- **For Tempering:**
  - 2 tbsp coconut oil
  - 1 tsp mustard seeds
  - 2-3 dried red chilies
  - 1 sprig curry leaves

---

#### 4. **Preparation Time**  
- **Preparation Time:** 20 minutes  
- **Cooking Time:** 30 minutes  
- **Total Time:** 50 minutes  

---

#### 5. **How to Prepare**  
1. Cook Vegetables: Boil the raw banana and yam with turmeric powder and a little salt until tender. Drain and set aside.  
2. Cook Lentils: Pressure cook soaked chana dal until soft but not mushy. Set aside.  
3. Prepare Coconut Paste: Grind grated coconut, cumin seeds, and green chilies into a smooth paste using little water.  
4. Combine: In a pan, mix cooked vegetables and lentils. Add the coconut paste and simmer for 5-7 minutes until well blended.  
5. Temper: Heat coconut oil in a small pan. Add mustard seeds, dried red chilies, and curry leaves. Pour this over the curry.  
6. Serve: Mix well and serve hot as part of a festive meal.

---

#### 6. **Tips**  
- Add roasted coconut for an authentic Kerala flavor.  
- Adjust the spice level by varying the number of green chilies.  

---

#### 7. **Serving Suggestions**  
- Serve hot with steamed rice and papadam.  
- Pairs well with other Onam Sadhya dishes like avial and sambar.  

---

#### 8. **Nutritional Information**  
- **Calories:** 220 kcal  
- **Protein:** 6 g  
- **Carbohydrates:** 30 g  
- **Fat:** 8 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "Not Available"

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "image_url/kootu_curry.jpg",  # Example placeholder for photo URL
    "Region": "Kerala, South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Vegetarian, Traditional",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": 200,  # Approximate value
    "Saturated Fat": 6,  # Approximate value
    "Sugar": 2,  # Approximate value
    "Type": "Vegetable Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Rich in Plant Protein"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Kootu Curry\n\n#### 2. **Description**  \n> Ko...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Kootu Curry is a traditional Kerala dish serve...      Not Available
#
#                        Photo               Region  Time of Eating (B)  \
# 0  image_url/kootu_curry.jpg  Kerala, South India               False
#
#    Time of Eating (L)  Time of Eating (D)                Food Type  Ratings  \
# 0                True                True  Vegetarian, Traditional      4.8
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar             Type  \
# 0  ...       6           0    200             6      2  Vegetable Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Kootu Curry\n\n#### 2. **Description**  \n> Ko...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Kootu Curry is a traditional Kerala dish serve...      Not Available
#
#                        Photo               Region  Time of Eating (B)  \
# 0  image_url/kootu_curry.jpg  Kerala, South India               False
#
#    Time of Eating (L)  Time of Eating (D)                Food Type  Ratings  \
# 0                True                True  Vegetarian, Traditional      4.8
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar             Type  \
# 0  ...       6           0    200             6      2  Vegetable Curry
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Potato Kurma

#### 2. **Description**  
> Potato Kurma is a flavorful and aromatic South Indian dish made with potatoes simmered in a coconut-based gravy. It is a perfect accompaniment to chapatis, parathas, or even steamed rice.

---

#### 3. **Ingredients**  
- **For Gravy:**
  - 2 large potatoes (boiled and cubed)
  - 1 large onion (finely chopped)
  - 1 large tomato (finely chopped)
  - 1/4 cup grated coconut
  - 1 tsp ginger-garlic paste
  - 2 green chilies (slit)
  - 1 tsp fennel seeds
  - 1 tsp turmeric powder
  - 2 tsp coriander powder
  - 1 tsp garam masala
  - Salt (to taste)
  - Water (as required)
- **For Tempering:**
  - 2 tbsp oil
  - 1 tsp mustard seeds
  - 1 sprig curry leaves

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 25 minutes  
- **Total Time:** 40 minutes  

---

#### 5. **How to Prepare**  
1. Heat oil in a pan and add mustard seeds. Once they splutter, add curry leaves, fennel seeds, and green chilies.  
2. Add the chopped onions and sauté until golden brown. Add ginger-garlic paste and cook until the raw smell goes away.  
3. Mix in the chopped tomatoes and cook until they become soft and mushy.  
4. Add turmeric powder, coriander powder, garam masala, and salt. Stir well.  
5. Blend the grated coconut with a little water to make a smooth paste. Add this paste to the pan and mix thoroughly.  
6. Add boiled potato cubes and enough water to reach your desired gravy consistency. Simmer for 10-15 minutes.  
7. Serve hot, garnished with fresh coriander leaves.  

---

#### 6. **Tips**  
- For a creamier texture, add cashew paste instead of coconut paste.  
- Pair it with fluffy puris for a classic combination.  

---

#### 7. **Serving Suggestions**  
- Serve Potato Kurma with chapatis, puris, or even steamed basmati rice.  
- Garnish with chopped coriander for added flavor.  

---

#### 8. **Nutritional Information**  
- **Calories:** 220 kcal  
- **Protein:** 4 g  
- **Carbohydrates:** 32 g  
- **Fat:** 10 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # Default value for missing keys

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Placeholder for image URL",
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Example for lunch
    "Time of Eating (D)": True,  # Example for dinner
    "Food Type": "Gluten-Free, Vegan-Friendly",
    "Ratings": 4.8,
    "Cholesterol": 0,
    "Sodium": "Low",
    "Saturated Fat": "Low",
    "Sugar": "Minimal",
    "Type": "Curry/Side Dish",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch/Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Protein Rich"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Potato Kurma\n\n#### 2. **Description**  \n> P...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Potato Kurma is a flavorful and aromatic South...                N/A
#
#                        Photo       Region  Time of Eating (B)  \
# 0  Placeholder for image URL  South India               False
#
#    Time of Eating (L)  Time of Eating (D)                    Food Type  \
# 0                True                True  Gluten-Free, Vegan-Friendly
#
#    Ratings  ... Protein Cholesterol Sodium Saturated Fat    Sugar  \
# 0      4.8  ...       4           0    Low           Low  Minimal
#
#               Type Food Type (Veg/Non-Veg/Vegan)  \
# 0  Curry/Side Dish                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch/Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Potato Kurma\n\n#### 2. **Description**  \n> P...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Potato Kurma is a flavorful and aromatic South...                N/A
#
#                        Photo       Region  Time of Eating (B)  \
# 0  Placeholder for image URL  South India               False
#
#    Time of Eating (L)  Time of Eating (D)                    Food Type  \
# 0                True                True  Gluten-Free, Vegan-Friendly
#
#    Ratings  ... Protein Cholesterol Sodium Saturated Fat    Sugar  \
# 0      4.8  ...       4           0    Low           Low  Minimal
#
#               Type Food Type (Veg/Non-Veg/Vegan)  \
# 0  Curry/Side Dish                           Veg
#
#   Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch/Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
import pandas as pd
import re

# Recipe text for Vendakkai Puli Kuzhambu
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Vendakkai Puli Kuzhambu (Okra Tamarind Curry)

#### 2. **Description**  
> Vendakkai Puli Kuzhambu is a tangy and flavorful South Indian curry made with okra and tamarind. This curry is a perfect accompaniment for steamed rice and is packed with spices that create a lip-smacking balance of flavors.

---

#### 3. **Ingredients**  
- **For Curry:**
  - 200 g okra (cut into 2-inch pieces)
  - 1 lemon-sized ball of tamarind (soaked and extracted)
  - 2 tbsp sesame oil
  - 1 tsp mustard seeds
  - 1/2 tsp fenugreek seeds
  - 1 sprig of curry leaves
  - 2-3 dried red chilies
  - 1 medium-sized onion (finely chopped)
  - 1 medium-sized tomato (finely chopped)
  - 1 tbsp sambar powder
  - 1/4 tsp turmeric powder
  - Salt to taste
  - Water as needed

---

#### 4. **Preparation Time**  
- **Preparation Time:** 15 minutes  
- **Cooking Time:** 20 minutes  
- **Total Time:** 35 minutes  

---

#### 5. **How to Prepare**  
1. Wash and pat dry the okra. Cut into 2-inch pieces.  
2. Heat oil in a pan and sauté the okra until slightly golden. Remove and set aside.  
3. In the same pan, add mustard seeds. Once they splutter, add fenugreek seeds, curry leaves, and dried red chilies.  
4. Add chopped onions and sauté until translucent, followed by tomatoes. Cook until tomatoes turn mushy.  
5. Add tamarind extract, turmeric powder, sambar powder, and salt. Mix well and bring to a boil.  
6. Add the sautéed okra to the curry and simmer for 10 minutes.  
7. Adjust the consistency with water as needed. Serve hot with steamed rice.

---

#### 6. **Tips**  
- Ensure the okra is dry before cutting to avoid sliminess.  
- Add a teaspoon of jaggery to balance the tanginess of the tamarind.  

---

#### 7. **Serving Suggestions**  
- Serve with hot steamed rice and papadam.  
- Pair with a side of poriyal or kootu for a complete South Indian meal.  

---

#### 8. **Nutritional Information**  
- **Calories:** 180 kcal  
- **Protein:** 5 g  
- **Carbohydrates:** 25 g  
- **Fat:** 5 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    if match:
        extracted_data[key] = match.group(1).strip()
    else:
        extracted_data[key] = "N/A"  # Ensure no null values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Fill additional columns with default values
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "Image_Not_Available",
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,
    "Time of Eating (D)": True,
    "Food Type": "Vegetarian, Tangy",
    "Ratings": 4.5,
    "Cholesterol": 0,
    "Sodium": 300,
    "Saturated Fat": 1,
    "Sugar": 3,
    "Type": "Curry",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Rich in Fiber"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Vendakkai Puli Kuzhambu (Okra Tamarind Curry)\...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Vendakkai Puli Kuzhambu is a tangy and flavorf...                N/A
#
#                  Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Image_Not_Available  South India               False                True
#
#    Time of Eating (D)          Food Type  Ratings  ... Protein Cholesterol  \
# 0                True  Vegetarian, Tangy      4.5  ...       5           0
#
#   Sodium Saturated Fat  Sugar   Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    300             1      3  Curry                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0          Rich in Fiber
#
# [1 rows x 23 columns]

# %%
df
# Out:
#                                                 Name  \
# 0  Vendakkai Puli Kuzhambu (Okra Tamarind Curry)\...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Vendakkai Puli Kuzhambu is a tangy and flavorf...                N/A
#
#                  Photo       Region  Time of Eating (B)  Time of Eating (L)  \
# 0  Image_Not_Available  South India               False                True
#
#    Time of Eating (D)          Food Type  Ratings  ... Protein Cholesterol  \
# 0                True  Vegetarian, Tangy      4.5  ...       5           0
#
#   Sodium Saturated Fat  Sugar   Type  Food Type (Veg/Non-Veg/Vegan)  \
# 0    300             1      3  Curry                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# 0          Rich in Fiber
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Tomato Rasam

#### 2. **Description**  
> Tomato Rasam is a tangy and flavorful South Indian soup made with ripe tomatoes, tamarind, and a blend of spices. It is commonly served as an appetizer or alongside rice.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 3 ripe tomatoes, chopped
  - 1 tablespoon tamarind paste
  - 3 cups water
- **Spices:**
  - 1 teaspoon mustard seeds
  - 1/2 teaspoon cumin seeds
  - 1/4 teaspoon turmeric powder
  - 1-2 dried red chilies
  - 1 sprig curry leaves
  - 1 teaspoon black pepper powder
  - 1 tablespoon rasam powder
  - Salt (to taste)
- **Tempering:**
  - 1 tablespoon ghee (clarified butter)
  - Fresh coriander leaves (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 15 minutes  
- **Total Time:** 25 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Base: Boil the chopped tomatoes with water and tamarind paste until soft. Mash them well or blend into a smooth mixture.  
2. Add Spices: Add turmeric powder, pepper powder, rasam powder, and salt. Bring the mixture to a gentle boil.  
3. Tempering: Heat ghee in a small pan. Add mustard seeds, cumin seeds, dried red chilies, and curry leaves. Let them splutter.  
4. Combine: Pour the tempering over the rasam. Stir well and let it simmer for a few minutes.  
5. Garnish & Serve: Garnish with fresh coriander leaves and serve hot with rice or enjoy as a soup.  

---

#### 6. **Tips**  
- Use fresh tamarind for a more authentic flavor.  
- Adjust spice levels based on your taste preference.  

---

#### 7. **Serving Suggestions**  
- Serve with hot steamed rice and ghee for a classic South Indian meal.  
- Enjoy as a light appetizer or comfort soup.  

---

#### 8. **Nutritional Information**  
- **Calories:** 80 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 12 g  
- **Fat:** 3 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "N/A"  # Ensure no null values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Populate additional fields
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "https://example.com/tomato_rasam.jpg",  # Placeholder image URL
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Typically consumed for lunch
    "Time of Eating (D)": True,  # Often consumed for dinner too
    "Food Type": "Comfort Food, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 30,  # Approximate value
    "Saturated Fat": 1,
    "Sugar": 1,  # Approximate value
    "Type": "Soup/Stew",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Rich in Antioxidants"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Tomato Rasam\n\n#### 2. **Description**  \n> T...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Tomato Rasam is a tangy and flavorful South In...                N/A
#
#                                   Photo       Region  Time of Eating (B)  \
# 0  https://example.com/tomato_rasam.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)                  Food Type  Ratings  \
# 0                True                True  Comfort Food, Gluten-Free        5
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0  ...       2           0     30             1      1  Soup/Stew
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Tomato Rasam\n\n#### 2. **Description**  \n> T...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Tomato Rasam is a tangy and flavorful South In...                N/A
#
#                                   Photo       Region  Time of Eating (B)  \
# 0  https://example.com/tomato_rasam.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)                  Food Type  Ratings  \
# 0                True                True  Comfort Food, Gluten-Free        5
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0  ...       2           0     30             1      1  Soup/Stew
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
import pandas as pd
import re

# Recipe text
recipe_text = """
### **Recipe Template**

#### 1. **Dish Name**  
> Tomato Rasam

#### 2. **Description**  
> Tomato Rasam is a tangy and flavorful South Indian soup made with ripe tomatoes, tamarind, and a blend of spices. It is commonly served as an appetizer or alongside rice.

---

#### 3. **Ingredients**  
- **Main Ingredients:**
  - 3 ripe tomatoes, chopped
  - 1 tablespoon tamarind paste
  - 3 cups water
- **Spices:**
  - 1 teaspoon mustard seeds
  - 1/2 teaspoon cumin seeds
  - 1/4 teaspoon turmeric powder
  - 1-2 dried red chilies
  - 1 sprig curry leaves
  - 1 teaspoon black pepper powder
  - 1 tablespoon rasam powder
  - Salt (to taste)
- **Tempering:**
  - 1 tablespoon ghee (clarified butter)
  - Fresh coriander leaves (for garnish)

---

#### 4. **Preparation Time**  
- **Preparation Time:** 10 minutes  
- **Cooking Time:** 15 minutes  
- **Total Time:** 25 minutes  

---

#### 5. **How to Prepare**  
1. Prepare Base: Boil the chopped tomatoes with water and tamarind paste until soft. Mash them well or blend into a smooth mixture.  
2. Add Spices: Add turmeric powder, pepper powder, rasam powder, and salt. Bring the mixture to a gentle boil.  
3. Tempering: Heat ghee in a small pan. Add mustard seeds, cumin seeds, dried red chilies, and curry leaves. Let them splutter.  
4. Combine: Pour the tempering over the rasam. Stir well and let it simmer for a few minutes.  
5. Garnish & Serve: Garnish with fresh coriander leaves and serve hot with rice or enjoy as a soup.  

---

#### 6. **Tips**  
- Use fresh tamarind for a more authentic flavor.  
- Adjust spice levels based on your taste preference.  

---

#### 7. **Serving Suggestions**  
- Serve with hot steamed rice and ghee for a classic South Indian meal.  
- Enjoy as a light appetizer or comfort soup.  

---

#### 8. **Nutritional Information**  
- **Calories:** 80 kcal  
- **Protein:** 2 g  
- **Carbohydrates:** 12 g  
- **Fat:** 3 g  
"""

# Define regex patterns for extracting relevant data
patterns = {
    "Name": r"#### 1\. \*\*Dish Name\*\*.*?> (.+)",
    "Desc (Kirusa type of writing)": r"#### 2\. \*\*Description\*\*.*?> (.+)",
    "Ingredients": r"#### 3\. \*\*Ingredients\*\*\n(.+?)\n\n---",
    "Preparation Time": r"Preparation Time:\*\* (.+?)\n",
    "Cooking Time": r"Cooking Time:\*\* (.+?)\n",
    "Total Time": r"Total Time:\*\* (.+?)\n",
    "How to Prepare": r"#### 5\. \*\*How to Prepare\*\*\n(.+?)\n\n---",
    "Tips": r"#### 6\. \*\*Tips\*\*\n(.+?)\n\n---",
    "Serving Suggestions": r"#### 7\. \*\*Serving Suggestions\*\*\n(.+?)\n\n---",
    "Calories": r"Calories:\*\* (\d+)",
    "Protein": r"Protein:\*\* ([\d.]+)",
    "Fat": r"Fat:\*\* ([\d.]+)"
}

# Extract data using regex
extracted_data = {}
for key, pattern in patterns.items():
    match = re.search(pattern, recipe_text, re.DOTALL)
    extracted_data[key] = match.group(1).strip() if match else "N/A"  # Ensure no null values

# Prepare DataFrame columns
columns = [
    "Name", "Desc (Kirusa type of writing)", "Desc (Preparation)", "Photo", "Region",
    "Time of Eating (B)", "Time of Eating (L)", "Time of Eating (D)", "Food Type", "Ratings",
    "Ingredients", "Calories", "Fat", "Protein", "Cholesterol", "Sodium", "Saturated Fat",
    "Sugar", "Type", "Food Type (Veg/Non-Veg/Vegan)", "Category (Breakfast/Lunch/Dinner/Snack/Beverages)",
    "Category (Diabetic/BP)", "Category (Muscle Gain)"
]

# Populate additional fields
extracted_data.update({
    "Desc (Preparation)": extracted_data.get("How to Prepare"),
    "Photo": "https://example.com/tomato_rasam.jpg",  # Placeholder image URL
    "Region": "South India",
    "Time of Eating (B)": False,
    "Time of Eating (L)": True,  # Typically consumed for lunch
    "Time of Eating (D)": True,  # Often consumed for dinner too
    "Food Type": "Comfort Food, Gluten-Free",
    "Ratings": 5,
    "Cholesterol": 0,
    "Sodium": 30,  # Approximate value
    "Saturated Fat": 1,
    "Sugar": 1,  # Approximate value
    "Type": "Soup/Stew",
    "Food Type (Veg/Non-Veg/Vegan)": "Veg",
    "Category (Breakfast/Lunch/Dinner/Snack/Beverages)": "Lunch, Dinner",
    "Category (Diabetic/BP)": "Diabetic Friendly",
    "Category (Muscle Gain)": "Rich in Antioxidants"
})

# Convert the extracted data into a DataFrame
df = pd.DataFrame([extracted_data], columns=columns)

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  Tomato Rasam\n\n#### 2. **Description**  \n> T...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Tomato Rasam is a tangy and flavorful South In...                N/A
#
#                                   Photo       Region  Time of Eating (B)  \
# 0  https://example.com/tomato_rasam.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)                  Food Type  Ratings  \
# 0                True                True  Comfort Food, Gluten-Free        5
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0  ...       2           0     30             1      1  Soup/Stew
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...

# %%
df
# Out:
#                                                 Name  \
# 0  Tomato Rasam\n\n#### 2. **Description**  \n> T...
#
#                        Desc (Kirusa type of writing) Desc (Preparation)  \
# 0  Tomato Rasam is a tangy and flavorful South In...                N/A
#
#                                   Photo       Region  Time of Eating (B)  \
# 0  https://example.com/tomato_rasam.jpg  South India               False
#
#    Time of Eating (L)  Time of Eating (D)                  Food Type  Ratings  \
# 0                True                True  Comfort Food, Gluten-Free        5
#
#    ... Protein Cholesterol Sodium Saturated Fat  Sugar       Type  \
# 0  ...       2           0     30             1      1  Soup/Stew
#
#    Food Type (Veg/Non-Veg/Vegan)  \
# 0                            Veg
#
#    Category (Breakfast/Lunch/Dinner/Snack/Beverages) Category (Diabetic/BP)  \
# 0                                      Lunch, Dinner      Diabetic Friendly
#
#   Category (Muscle Gain)
# ...
